# %% [markdown]
# # 🏥 Limpieza de Datos de Internaciones
#
# ## 🎯 Objetivo:
#   Optimizar el dataset de internaciones para su exploración clínica y la construcción de dashboards, claros y útiles para stakeholders hospitalarios.
#
# ---
#
# ## Etapas de preparación del dataframe:
#
# ## 1️⃣ Observación Inicial y Unión de DataFrames:
#
# - Se realiza una inspección preliminar de los DataFrames disponibles (`df_egreso2020`, `df_egreso2021`, `df_egreso2022`).
# - Se identifican claves comunes para realizar la unión lógica entre tablas.
# - Se verifica la consistencia temporal y la unicidad de las claves.
#
# ## 2️⃣ Eliminación de Columnas Innecesarias
#
# - Se identifican columnas irrelevantes para el análisis clínico o redundantes (por ejemplo: `des_dgi_1`, `des_dge_p`).
# - Se eliminan campos sin valor analítico o que no aportan a la visualización.
# - Se documenta cada columna eliminada y su justificación clínica o técnica.
#
# ## 3️⃣ Tratamiento de Valores Nulos o Faltantes
#
# - Se analiza la proporción de nulos por columna y su impacto en el análisis.
# - Se documenta cada decisión de imputación o eliminación.
#
# ## 4️⃣ Transformación y Estandarización de Columnas
#
# - Se normalizan formatos de fecha (`YYYY-MM-DD`) y se extraen componentes útiles (`mes`, `año`).
# - Se estandarizan nombres de servicios clínicos, diagnósticos y categorías etarias.
#
#
# ---
# ## Conclusión:
# _Esta limpieza permite construir dashboards clínicos escalables, con KPIs relevantes y visualizaciones interactivas que facilitaran la toma de decisiones operativas y estratégicas._
#
# ---

# %% [markdown]
# ## 1.  Carga y Exploración Inicial

# %%
import pandas as pd
import os
import pandas as pd
import unicodedata
import numpy as np

# %%
# Ruta base desde el directorio del proyecto
BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), ".."))
DATA_DIR = os.path.join(BASE_DIR, "data")

def cargar_csv(nombre_archivo):
    ruta_completa = os.path.join(DATA_DIR, nombre_archivo)
    try:
        return pd.read_csv(ruta_completa)
    except FileNotFoundError:
        print(f"⚠️ Archivo no encontrado: {ruta_completa}")
        return None


df_2020 = cargar_csv("egresos2020.csv")
df_2021 = cargar_csv("egresos2021.csv")
df_2022 = cargar_csv("egresos2022.csv")

# %%
# Agregamos la columna año y su respectivo año en cada dataset
df_2020["año"] = 2020
df_2021["año"] = 2021
df_2022["año"] = 2022

# %%
# Unimos los df
df_completo = pd.concat([df_2020, df_2021, df_2022], ignore_index=True)

# %%
# Observamos el df inicial
df_completo.head()
# Out:
#       aÒo  mes efector  idInt  idPac sex  edad ser  \
# 0  2020.0    4    HECA      1   6545   M  21.0  35
# 1  2020.0    3    HECA      2  12186   F  57.0  35
# 2  2020.0    1    HECA      3  17335   F  60.0  35
# 3  2020.0    1    HECA      4    518   M  52.0  66
# 4  2020.0    2    HECA      5  19373   M  40.0  89
#
#                                   des_ser  dgi_p  \
# 0  GUARDIA EMERGENCIA - MEDICINA URGENCIA    L03
# 1  GUARDIA EMERGENCIA - MEDICINA URGENCIA    N19
# 2  GUARDIA EMERGENCIA - MEDICINA URGENCIA  K62.5
# 3                    UROLOGIA - URINARIAS  Y84.6
# 4                        UNIDAD CORONARIA    T07
#
#                                   des_dgi_p dgi_1 des_dgi_1 dgi_2 des_dgi_2  \
# 0                                 CELULITIS   NaN       NaN   NaN       NaN
# 1       INSUFICIENCIA RENAL NO ESPECIFICADA   NaN       NaN   NaN       NaN
# 2                              PROCTORRAGIA   NaN       NaN   NaN       NaN
# 3                   CATETERIZACIÛN URINARIA   NaN       NaN   NaN       NaN
# 4  TRAUMATISMOS MULTIPLES -NO ESPECIFICADOS   NaN       NaN   NaN       NaN
#
#    dge_p                                 des_dge_p  dge_1  \
# 0    G09  SECUEL.DE ENF.INFLAM.DEL SIST.NERV.CENT.  J18.9
# 1    R99  OTRS.CAUS.MAL DEFIN.Y LAS NO ESP.DE MORT    NaN
# 2  C21.8   LESION SIT.CONTG.ANO CONDC.ANAL Y RECTO    NaN
# 3  N39.0  INFECCION VIAS URINARIAS SITIO NO ESPECI  K63.2
# 4    T07  TRAUMATISMOS MULTIPLES -NO ESPECIFICADOS    S72
#
#                   des_dge_1  dge_2                   des_dge_2  tipo_egreso  \
# 0  NEUMONIA NO ESPECIFICADA  A41.9  SEPTICEMIA NO ESPECIFICADA    Defuncion
# 1                       NaN    NaN                         NaN    Defuncion
# 2                       NaN    NaN                         NaN    Defuncion
# 3     FISTULA DEL INTESTINO    NaN                         NaN  Alta medica
# 4        FRACTURA DEL FEMUR    NaN                         NaN  Alta medica
#
#   sect                            des_sect  estada   año  anio
# 0   I0  AREA DE CUIDADOS INTERMEDIOS ALTOS     239  2020   NaN
# 1   I0  AREA DE CUIDADOS INTERMEDIOS ALTOS     133  2020   NaN
# 2   I0  AREA DE CUIDADOS INTERMEDIOS ALTOS      71  2020   NaN
# 3   I0  AREA DE CUIDADOS INTERMEDIOS ALTOS      74  2020   NaN
# 4   I0  AREA DE CUIDADOS INTERMEDIOS ALTOS      86  2020   NaN

# %% [markdown]
# ## 📋 Observaciones iniciales de la estructura del dataset:
#
#
# El dataset incluye registros clínicos anonimizados de pacientes internados en instituciones de salud. Cada fila representa una internación, y las columnas están organizadas por categoría temática para facilitar su análisis, limpieza y visualización posterior en Power BI.
#
# A continuación se presenta una tabla descriptiva de las columnas contenidas en el dataset:
#
# | Categoría                 | Columna           | Descripción                                                                 |
# |--------------------------|-------------------|-----------------------------------------------------------------------------|
# | 📅 Fecha de egreso        | `año`             | Año de egreso                                                               |
# |                          | `mes`             | Mes de egreso                                                               |
# |  Hospital               | `efector`         | Hospital de la internación                                                 |
# | 🆔 Identificadores        | `idint`           | Número de identificación de la internación                                 |
# |                          | `idpac`           | Número de identificación del paciente                                       |
# | 🧑‍⚕️ Datos del paciente    | `sexo`            | Sexo del paciente (`Femenino`, `Masculino`)                                 |
# |                          | `edad`            | Edad del paciente en años                                                  |
# | 🛌 Servicio de internación| `ser`             | Código del servicio médico que realiza la atención                         |
# |                          | `des_ser`         | Descripción del servicio de internación                                     |
# | 🩺 Diagnóstico de ingreso | `dgi_p`           | Código CIE10 del diagnóstico principal de ingreso                           |
# |                          | `des_dgi_p`       | Descripción del diagnóstico principal de ingreso                            |
# |                          | `dgi_1`           | Código CIE10 del diagnóstico secundario 1 de ingreso                        |
# |                          | `des_dgi_1`       | Descripción del diagnóstico secundario 1 de ingreso                         |
# |                          | `dgi_2`           | Código CIE10 del diagnóstico secundario 2 de ingreso                        |
# |                          | `des_dgi_2`       | Descripción del diagnóstico secundario 2 de ingreso                         |
# | 🏁 Diagnóstico de egreso  | `dge_p`           | Código CIE10 del diagnóstico principal de egreso                            |
# |                          | `des_dge_p`       | Descripción del diagnóstico principal de egreso                             |
# |                          | `dge_1`           | Código CIE10 del diagnóstico secundario 1 de egreso                         |
# |                          | `des_dge_1`       | Descripción del diagnóstico secundario 1 de egreso                          |
# |                          | `dge_2`           | Código CIE10 del diagnóstico secundario 2 de egreso                         |
# |                          | `des_dge_2`       | Descripción del diagnóstico secundario 2 de egreso                          |
# |  Tipo de egreso         | `tipo_egreso`     | Tipo de egreso (`Alta Médica`, `Defunción`, etc.)                          |
# |  Sector hospitalario    | `sect`            | Código del sector hospitalario de egreso                                   |
# |                          | `des_sect`        | Descripción del sector hospitalario de egreso                              |

# %% [markdown]
# ## 2. Limpieza de Columnas
#
# Para facilitar el manejo y la legibilidad del DataFrame, se realiza una estandarización de los nombres de las columnas:
#
# - Todos los nombres se convierten a minúsculas.
# - Se reemplazan los espacios por guiones bajos (`_`) para facilitar el manejo, la legibilidad y se estandarizaran los nombres de las columnas.
# - Se renombran algunas columnas para reflejar mejor su contenido o simplificar su uso.

# %%
# Visualizando todas las columnas del df 
print(df_completo.columns.tolist())
# Out:
# ['aÒo', 'mes', 'efector', 'idInt', 'idPac', 'sex', 'edad', 'ser', 'des_ser', 'dgi_p', 'des_dgi_p', 'dgi_1', 'des_dgi_1', 'dgi_2', 'des_dgi_2', 'dge_p', 'des_dge_p', 'dge_1', 'des_dge_1', 'dge_2', 'des_dge_2', 'tipo_egreso', 'sect', 'des_sect', 'estada', 'año', 'anio']

# %%
# Eliminando columnas innecesarias 
df_completo.drop(columns=["sect","aÒo", "anio", 'dgi_1', 'dgi_2','dge_1', 'dge_2','dgi_p', 'des_dge_1','des_dge_2','des_dgi_2', 'des_dgi_1','dge_p','ser'], inplace=True)

# %%
# Reenombrando columnas
df_completo.rename(columns={"sex": "sexo_paciente", "idInt": "id_internacion", "estada": "estadia_dias", "idPac":"id_paciente","des_dgi_p":"diagnostico_ingreso","des_dge_p":"diagnostico_egreso", "des_ser":"descripcion_servicio","edad":"edad_paciente"	}, inplace=True)

# %%
df_completo.head()
# Out:
#    mes efector  id_internacion  id_paciente sexo_paciente  edad_paciente  \
# 0    4    HECA               1         6545             M           21.0
# 1    3    HECA               2        12186             F           57.0
# 2    1    HECA               3        17335             F           60.0
# 3    1    HECA               4          518             M           52.0
# 4    2    HECA               5        19373             M           40.0
#
#                      descripcion_servicio  \
# 0  GUARDIA EMERGENCIA - MEDICINA URGENCIA
# 1  GUARDIA EMERGENCIA - MEDICINA URGENCIA
# 2  GUARDIA EMERGENCIA - MEDICINA URGENCIA
# 3                    UROLOGIA - URINARIAS
# 4                        UNIDAD CORONARIA
#
#                         diagnostico_ingreso  \
# 0                                 CELULITIS
# 1       INSUFICIENCIA RENAL NO ESPECIFICADA
# 2                              PROCTORRAGIA
# 3                   CATETERIZACIÛN URINARIA
# 4  TRAUMATISMOS MULTIPLES -NO ESPECIFICADOS
#
#                          diagnostico_egreso  tipo_egreso  \
# 0  SECUEL.DE ENF.INFLAM.DEL SIST.NERV.CENT.    Defuncion
# 1  OTRS.CAUS.MAL DEFIN.Y LAS NO ESP.DE MORT    Defuncion
# 2   LESION SIT.CONTG.ANO CONDC.ANAL Y RECTO    Defuncion
# 3  INFECCION VIAS URINARIAS SITIO NO ESPECI  Alta medica
# 4  TRAUMATISMOS MULTIPLES -NO ESPECIFICADOS  Alta medica
#
#                              des_sect  estadia_dias   año
# 0  AREA DE CUIDADOS INTERMEDIOS ALTOS           239  2020
# 1  AREA DE CUIDADOS INTERMEDIOS ALTOS           133  2020
# 2  AREA DE CUIDADOS INTERMEDIOS ALTOS            71  2020
# 3  AREA DE CUIDADOS INTERMEDIOS ALTOS            74  2020
# 4  AREA DE CUIDADOS INTERMEDIOS ALTOS            86  2020

# %% [markdown]
# ## 3. Manejo de valores ausentes/ Nulos
#
# - Identificación y gestión de los valores nulos en el dataset. La estrategia dependerá de la columna y la cantidad de nulos.

# %%
#3.1 Identificación de Valores Ausentes
# Contar valores nulos por columna
missing_values = df_completo.isnull().sum()
print("\nValores nulos por columna antes del tratamiento:")
print(missing_values[missing_values > 0])

# Calcular el porcentaje de valores nulos
missing_percentage = (df_completo.isnull().sum() / len(df_completo)) * 100
print("\nPorcentaje de valores nulos por columna antes del tratamiento:")
print(missing_percentage[missing_percentage > 0])

#3.2 Tratamiento de los NaNs: Eliminación de filas en valores nulos
df_completo = df_completo.dropna()
print(f'Registros restantes: {len(df_completo)}')
print(df_completo.info())
# Out:
# Valores nulos por columna antes del tratamiento:
# edad_paciente          1110
# diagnostico_ingreso    1586
# diagnostico_egreso     9884
# tipo_egreso              19
# dtype: int64
#
# Porcentaje de valores nulos por columna antes del tratamiento:
# edad_paciente           1.187521
# diagnostico_ingreso     1.696765
# diagnostico_egreso     10.574290
# tipo_egreso             0.020327
# dtype: float64
# Registros restantes: 81767
# <class 'pandas.core.frame.DataFrame'>
# Index: 81767 entries, 0 to 93471
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   mes                   81767 non-null  int64
#  1   efector               81767 non-null  object
#  2   id_internacion        81767 non-null  int64
#  3   id_paciente           81767 non-null  int64
#  4   sexo_paciente         81767 non-null  object
#  5   edad_paciente         81767 non-null  float64
#  6   descripcion_servicio  81767 non-null  object
#  7   diagnostico_ingreso   81767 non-null  object
#  8   diagnostico_egreso    81767 non-null  object
#  9   tipo_egreso           81767 non-null  object
#  10  des_sect              81767 non-null  object
#  11  estadia_dias          81767 non-null  int64
#  12  año                   81767 non-null  int64
# dtypes: float64(1), int64(5), object(7)
# memory usage: 8.7+ MB
# None

# %%
#3.2 Tratamiento de los NaNs: Eliminación de filas en valores nulos
df_completo = df_completo.dropna()
print(f'Registros restantes: {len(df_completo)}')
print(df_completo.info())
# Out:
# Registros restantes: 81767
# <class 'pandas.core.frame.DataFrame'>
# Index: 81767 entries, 0 to 93471
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   mes                   81767 non-null  int64
#  1   efector               81767 non-null  object
#  2   id_internacion        81767 non-null  int64
#  3   id_paciente           81767 non-null  int64
#  4   sexo_paciente         81767 non-null  object
#  5   edad_paciente         81767 non-null  float64
#  6   descripcion_servicio  81767 non-null  object
#  7   diagnostico_ingreso   81767 non-null  object
#  8   diagnostico_egreso    81767 non-null  object
#  9   tipo_egreso           81767 non-null  object
#  10  des_sect              81767 non-null  object
#  11  estadia_dias          81767 non-null  int64
#  12  año                   81767 non-null  int64
# dtypes: float64(1), int64(5), object(7)
# memory usage: 8.7+ MB
# None

# %% [markdown]
# ## 4. Transformación y Estandarización de columnas

# %% [markdown]
# 4.1  `tipo_egreso`:

# %%
# Observamos los valores únicos antes de la transformación:
print("\n Valores únicos originales en 'tipo_egreso':")
print(df_completo['tipo_egreso'].unique())

# Reemplazo de valor específico por versión estandarizada
df_completo['tipo_egreso'] = df_completo['tipo_egreso'].replace('Propia voluntad', 'Retiro Voluntario')
df_completo['tipo_egreso'] = df_completo['tipo_egreso'].replace('Alta tecnica', 'Alta medica')
# Eliminando registros no pertinentes
valores_a_excluir = ['Sin orden', 'Hospital dia']
df_completo = df_completo[~df_completo['tipo_egreso'].isin(valores_a_excluir)]

#valores únicos después de la transformación
print("\n Valores únicos luego de la transformación en 'tipo_egreso':")
print(df_completo['tipo_egreso'].unique())
# Out:
#  Valores únicos originales en 'tipo_egreso':
# ['Defuncion' 'Alta medica' 'Fuga' 'Traslado' 'Propia voluntad'
#  'Alta tecnica' 'Sin orden' 'Hospital dia']
#
#  Valores únicos luego de la transformación en 'tipo_egreso':
# ['Defuncion' 'Alta medica' 'Fuga' 'Traslado' 'Retiro Voluntario']

# %% [markdown]
# 4.2  `descripcion_servicio`:

# %%
# Valores originales  y únicos de la columna  
print(df_completo['descripcion_servicio'].unique())
# Out:
# ['GUARDIA EMERGENCIA - MEDICINA URGENCIA' 'UROLOGIA - URINARIAS'
#  'UNIDAD CORONARIA' 'NEUROCIRUGIA' 'CIRUGIA GENERAL - CLINICA QUIRURGICA'
#  'TRAUMATOLOGIA TRAUMATOLO Y ORTOP- YESO' 'CARDIOLOGIA'
#  'CLINICA MEDICA - MEDICINA INTERNA' 'GINECOLOGIA' 'QUEMADOS' 'NEFROLOGIA'
#  'NEUROLOGIA' 'HEMATOLOGIA' 'OFTALMOLOGIA' 'CIRUGIA PLASTICA'
#  'TERAPIA INTENSIVA - CUIDADOS INTENSIVOS' 'ENFERMERIA'
#  'GUARDIA AMBULATORIA MOVILES' 'CIRUGIA MAXILO FACIAL' 'SALUD MENTAL'
#  'OTORRINOLARINGOLOGIA O R L' 'GENETICA - ANDROLOGIA'
#  'MEDICINA GENERAL CLINICA GENERAL' 'ONCOLOGIA CANCEROLOGIA'
#  'CIRUGIA BUCO MAXILO FACIAL' 'GERIATRIA' 'HEMODINAMIA'
#  'ADMISION DE INTERNACION' 'NEUMONOLOGIA VIAS RESPIRATORIAS'
#  'GASTROENTEROLOGIA' 'ALCOHOLISMO - DROGADICCION  MIXTO'
#  'TERAPIA INTENSIVA INFANTIL' 'GUARDIA PEDIATRIA' 'HEMATOLOGIA INFANTIL'
#  'CIRUGIA GENERAL INFANTIL' 'CLINICA MEDICA INFANTIL-MEDICINA INTERNA'
#  'INFECTOLOGIA E INFECCIOSAS INFANTIL' 'QUEMADOS INFANTIL'
#  'HOSPITAL DE DIA' 'TERAPIA INTENSIVA NEONATOLOGICA'
#  'GUARDIA NEONATOLOGICA' 'OBSTETRICIA' 'GUARDIA OBSTETRICA'
#  'CUIDADOS ESPECIALES NEONATOLOGICOS'
#  'TOCOGINECOLOGIA - OBSTETRICIA Y GINECOLO' 'GUARDIA COVID19'
#  'CUIDADOS INTERMEDIOS' 'PEDIATRIA GENERAL LACTANTES' 'FISIATRIA'
#  'MEDICINA LEGAL' 'PATOLOGIA MAMARIA' 'PATOLOGIA HIDROELECTROLITICA'
#  'CIRUGIA CARDIOVASCULAR' 'TRABAJO SOCIAL'
#  'CIRUGIA GENERAL Y GINECOLOGICA'
#  'TRAUMATOLOGIA INFANTIL - ORTOPEDIA Y TRA'
#  'CENTRO INTEGRAL DE LA AUDICION']

# %%
mapa_servicios = {
    "GUARDIA EMERGENCIA - MEDICINA URGENCIA": "Guardia",
    "GUARDIA AMBULATORIA MOVILES": "Guardia",
    "GUARDIA PEDIATRIA": "Guardia",
    "GUARDIA OBSTETRICA": "Guardia",
    "GUARDIA NEONATOLOGICA": "Guardia",
    "GUARDIA COVID19": "Guardia",
    
    "CLINICA MEDICA - MEDICINA INTERNA": "Clínica Médica",
    "CLINICA MEDICA INFANTIL-MEDICINA INTERNA": "Clínica Médica",
    "MEDICINA GENERAL CLINICA GENERAL": "Clínica Médica",

    "CIRUGIA CARDIOVASCULAR": "Cirugía",
    "CIRUGIA GENERAL - CLINICA QUIRURGICA": "Cirugía",
    "CIRUGIA GENERAL Y GINECOLOGICA": "Cirugía",
    "CIRUGIA GENERAL INFANTIL": "Cirugía",
    "CIRUGIA BUCO MAXILO FACIAL": "Cirugía",
    "CIRUGIA MAXILO FACIAL": "Cirugía",
    "CIRUGIA PLASTICA": "Cirugía",
    "NEUROCIRUGIA": "Cirugía",

    "TRAUMATOLOGIA TRAUMATOLO Y ORTOP- YESO": "Traumatología y Ortopedia",
    "TRAUMATOLOGIA INFANTIL - ORTOPEDIA Y TRA": "Traumatología y Ortopedia",

    "TERAPIA INTENSIVA - CUIDADOS INTENSIVOS": "UTI",
    "TERAPIA INTENSIVA INFANTIL": "UTI",
    "TERAPIA INTENSIVA NEONATOLOGICA": "UTI",
    "CUIDADOS INTERMEDIOS": "UTI",
    "CUIDADOS INTERMEDIOS BAJOS": "UTI",
    "UNIDAD CORONARIA": "Unidad Coronaria",

    "OBSTETRICIA": "Obstetricia",
    "GINECOLOGIA": "Ginecología",
    "TOCOGINECOLOGIA - OBSTETRICIA Y GINECOLO": "Obstetricia",
    "CARDIOLOGIA": "Cardiología",
    "NEUMONOLOGIA VIAS RESPIRATORIAS": "Neumonología",
    "QUEMADOS": "Quemados",
    "QUEMADOS INFANTIL": "Quemados",

    "SALUD MENTAL": "Salud Mental",
    "ALCOHOLISMO - DROGADICCION  MIXTO": "Salud Mental",

    "CUIDADOS ESPECIALES NEONATOLOGICOS": "Neonatología",
    "UROLOGIA - URINARIAS": "Urología",
    "OFTALMOLOGIA": "Oftalmología",
    "FISIATRIA": "Fisiatría",
    
    # Servicios que no seran categorizables → se marcan como NNan para su futura eliminación
    "OFTALMOLOGIA": np.nan,
    "PEDIATRIA GENERAL LACTANTES": np.nan,
    "INFECTOLOGIA E INFECCIOSAS INFANTIL": np.nan,
    "GERIATRIA": np.nan,
    "CENTRO INTEGRAL DE LA AUDICION": np.nan,
    "TOXICOLOGIA INFANTIL": np.nan,
    "OTORRINOLARINGOLOGIA O R L": np.nan,
    "ADMISION DE INTERNACION": np.nan,
    "ENFERMERIA": np.nan,
    "HOSPITAL DE DIA": np.nan,
    "MEDICINA LEGAL": np.nan,
    "TRABAJO SOCIAL": np.nan,
    "GASTROENTEROLOGIA": np.nan,
    "DIAGNOSTICO POR IMAGENES": np.nan,
    "ONCOLOGIA CANCEROLOGIA": np.nan,
    "HEMODINAMIA": np.nan,
    "GENETICA - ANDROLOGIA": np.nan,
    "PATOLOGIA MAMARIA": np.nan,
    "PATOLOGIA HIDROELECTROLITICA": np.nan,
    "HEMATOLOGIA": np.nan,
    "HEMATOLOGIA INFANTIL": np.nan,
    "ADMISION DE INTERNACION": np.nan,
    
}

# %%
df_completo['servicio_internacion'] = df_completo['descripcion_servicio'].map(mapa_servicios)

# %%
# Eliminamos la columna original y la  remplazamos por la nueva , con las transformaciones realizadas
df_completo = df_completo.dropna(subset=["servicio_internacion"])

# %%
# Observamos los valores finales de la columna
df_completo['servicio_internacion'].unique()
# Out:
# array(['Guardia', 'Urología', 'Unidad Coronaria', 'Cirugía',
#        'Traumatología y Ortopedia', 'Cardiología', 'Clínica Médica',
#        'Ginecología', 'Quemados', 'UTI', 'Salud Mental', 'Neumonología',
#        'Obstetricia', 'Neonatología', 'Fisiatría'], dtype=object)

# %%
#Se elimina la columna original `descripcion_servicio` luego de consolidar los valores categorizados en `tipo_servicio`.
df_completo.drop(columns=['descripcion_servicio'], inplace=True)

# %% [markdown]
# 4.3  `sexo_paciente`:

# %%
df_completo['sexo_paciente'].unique()
df_completo["sexo_paciente"].value_counts()
# Out:
# sexo_paciente
# F    45013
# M    34216
# D       87
# Name: count, dtype: int64

# %%
#Eliminando valores distintos a F y M.
df_completo = df_completo[df_completo['sexo_paciente'] != "D"]

# %% [markdown]
# 4.4 `edad_paciente`:

# %%
# Convertir a tipo numérico (forzando errores a NaN si hay strings o símbolos)
df_completo['edad_paciente'] = pd.to_numeric(df_completo['edad_paciente'], errors='coerce').astype("Int64")

# Verificar valores nulos o extremos
print("Valores nulos:", df_completo['edad_paciente'].isna().sum())
print("Valores fuera de rango:", df_completo[(df_completo['edad_paciente'] < 0) | (df_completo['edad_paciente'] > 95)].shape[0])
# Out:
# Valores nulos: 0
# Valores fuera de rango: 7

# %%
# Observando los registros fuera de rango
df_completo.loc[(df_completo['edad_paciente'] < 0) | (df_completo['edad_paciente'] > 95)].T
# Out:
#                                                          5073   \
# mes                                                          8
# efector                                                   HECA
# id_internacion                                            5074
# id_paciente                                              21697
# sexo_paciente                                                F
# edad_paciente                                               96
# diagnostico_ingreso   TRAUMATISMO SUPEFIC.DE LA CADERA Y MUSLO
# diagnostico_egreso    FRACTURA DEL FÈMUR, PARTE NO ESPECIFICAD
# tipo_egreso                                          Defuncion
# des_sect                    AREA DE CUIDADOS INTERMEDIOS BAJOS
# estadia_dias                                                 6
# año                                                       2020
# servicio_internacion                 Traumatología y Ortopedia
#
#                                             8911   \
# mes                                             2
# efector                                       HIC
# id_internacion                                907
# id_paciente                                 19963
# sexo_paciente                                   F
# edad_paciente                                  97
# diagnostico_ingreso          ILEO NO ESPECIFICADO
# diagnostico_egreso           ILEO NO ESPECIFICADO
# tipo_egreso                              Traslado
# des_sect              HIC - SHOCK ROOM (CAMILLAS)
# estadia_dias                                    1
# año                                          2020
# servicio_internacion                      Guardia
#
#                                                32250  \
# mes                                                5
# efector                                         HECA
# id_internacion                                  3277
# id_paciente                                    22571
# sexo_paciente                                      F
# edad_paciente                                     96
# diagnostico_ingreso      TRASTORNO COGNOSCITIVO LEVE
# diagnostico_egreso    COVID-19 VIRUS NO IDENTIFICADO
# tipo_egreso                              Alta medica
# des_sect                 AREA DE EMERGENCIA PRIMARIA
# estadia_dias                                       2
# año                                             2021
# servicio_internacion                  Clínica Médica
#
#                                                        41781  \
# mes                                                        8
# efector                                                  HIC
# id_internacion                                          3502
# id_paciente                                            23695
# sexo_paciente                                              F
# edad_paciente                                             96
# diagnostico_ingreso                                   DISNEA
# diagnostico_egreso    INSUFICIENCIA CARDIACA NO ESPECIFICADA
# tipo_egreso                                         Traslado
# des_sect                             HIC - GUARDIA - (CAMAS)
# estadia_dias                                               1
# año                                                     2021
# servicio_internacion                                 Guardia
#
#                                               75758  \
# mes                                              11
# efector                                         HIC
# id_internacion                                 5605
# id_paciente                                     772
# sexo_paciente                                     M
# edad_paciente                                   107
# diagnostico_ingreso   COLICO RENAL, NO ESPECIFICADO
# diagnostico_egreso    COLICO RENAL, NO ESPECIFICADO
# tipo_egreso                             Alta medica
# des_sect                HIC - SHOCK ROOM (CAMILLAS)
# estadia_dias                                      1
# año                                            2022
# servicio_internacion                        Guardia
#
#                                                          83717  \
# mes                                                         11
# efector                                                   HNVV
# id_internacion                                            5644
# id_paciente                                                472
# sexo_paciente                                                M
# edad_paciente                                              107
# diagnostico_ingreso   TRAUMATISMOS MULTIPLES -NO ESPECIFICADOS
# diagnostico_egreso    FRACTURA COLUMNA VERTEB,NIVEL NO ESPECIF
# tipo_egreso                                        Alta medica
# des_sect                                        HNVV - GUARDIA
# estadia_dias                                                 1
# año                                                       2022
# servicio_internacion                                   Guardia
#
#                                         85584
# mes                                         4
# efector                                  HRSP
# id_internacion                           1379
# id_paciente                             22809
# sexo_paciente                               F
# edad_paciente                             201
# diagnostico_ingreso   PARTO UNICO POR CESAREA
# diagnostico_egreso    PARTO UNICO POR CESAREA
# tipo_egreso                       Alta medica
# des_sect                   HRSP - OBSTETRICIA
# estadia_dias                                3
# año                                      2022
# servicio_internacion              Obstetricia

# %%
# Eliminamos pacientes con edad mayor a 95 años
df_completo = df_completo[df_completo['edad_paciente'] <= 95]

# %% [markdown]
# 4.5 `diagnostico_ingreso`:

# %%
# Ver todos los valores únicos como lista completa
diagnosticos = df_completo['diagnostico_ingreso'].unique().tolist()

# %%
frecuencias = df_completo["diagnostico_ingreso"].value_counts(dropna=False)

# %%
# Mostrar todos los resultados sin truncamiento
'''pd.set_option("display.max_rows", None)
print(frecuencias)'''
# Out:
# 'pd.set_option("display.max_rows", None)\nprint(frecuencias)'

# %%
# Creamos un diccionario para renombrar los diagnosticos de ingreso y egreso asi podran ser más legibles e intepetrables para los analisis posteriores y para los stakeholders
diccionario_normalizado = {
    "PARTO UNICO ESPONT.PRESENT.CEFALIC.VERTI": "Parto único espontáneo",
    "ANOMALIA DINAMIC.DEL TRAB.PARTO NO ESPEC": "Anomalía dinámica del trabajo de parto",
    "DOLOR ABDOMINAL Y PELVICO": "Dolor abdominal y pélvico",
    "PARTO UNICO ESPONTANEO": "Parto único espontáneo",
    "COVID-19 VIRUS IDENTIFICADO": "COVID-19",
    "OTR.DOLORES ABDOMINALES Y LOS NO ESPECIF": "Otros dolores abdominales no especificados",
    "COVID-19 VIRUS NO IDENTIFICADO": "COVID-19",
    "DIARREA Y GASTROENTERITIS DE PRESUNTO OR": "Diarrea y gastroenteritis de origen infeccioso",
    "TRABAJO DE PARTO PROLONGADO NO ESPEC.": "Trabajo de parto prolongado",
    "NEUMONIA NO ESPECIFICADA": "Neumonía",
    "RUPTURA PREMATURA DE MEMBR.S/ESP": "Ruptura prematura de membranas",
    "PARTO CON CESAREA ELECTIVA": "Cesárea electiva",
    "PARTO UNICO POR CESAREA": "Parto único por cesárea",
    "NAUSEA Y VOMITO": "Náuseas y vómitos",
    "FIEBRE": "Fiebre",
    "CONVULSIONES -NO CLASIFICADAS EN OTRA P.": "Convulsiones no clasificadas",
    "TRAUMATISMO DE LA CABEZA NO ESPECIFICADO": "Traumatismo craneal no especificado",
    "DOLOR TORACICO": "Dolor torácico",
    "DISNEA": "Disnea",
    "TRAUMATISMOS MULTIPLES -NO ESPECIFICADOS": "Traumatismos múltiples",
    "OTR.ENFERM.PULM.OBSTRUCT.CRONIC.NO ESPE.": "EPOC no especificada",
    "INFECCION VIAS URINARIAS SITIO NO ESPECI": "Infección urinaria no especificada",
    "COLICO RENAL, NO ESPECIFICADO": "Cólico renal",
    "CEFALEA": "Cefalea",
    "OTROS RECIEN NACIDOS PRETERMINO": "Recién nacidos prematuros",
    "OTROS TRAUMAT.Y LOS NO ESPEC.DE LA CABEZ": "Otros traumatismos craneales",
    "ABSCESO PERIAPICAL SIN FISTULA": "Absceso dental sin fístula",
    "ESTADO ASMATICO": "Crisis asmática",
    "ABORTO MEDICO": "Aborto médico",
    "HIPERTENSION MATERNA, NO ESPECIFICADA": "Hipertensión materna",
    "ICTERICIA NEONATAL NO ESPECIFICADA": "Ictericia neonatal",
    "APENDICITIS AGUDA": "Apendicitis aguda",
    "DOLOR ABDOMINAL LOCALIZADO PARTE SUPERIO": "Dolor abdominal en epigastrio",
    "DOLOR LUMBAR": "Dolor lumbar",
    "CELULITIS": "Celulitis",
    "CELULITIS DE OTRAS PARTES DE LOS MIEMBRO": "Celulitis",
    "DOLOR PRECORDIAL": "Dolor precordial",
    "FIEBRE NO ESPECIFICADA": "Fiebre no especificada",
    "HIPERTENSION ESENCIAL (PRIMARIA)": "Hipertensión esencial",
    "APENDICITIS AGUDA NO ESPECIFICADA": "Apendicitis aguda",
    "TRABAJO DE PARTO PREMATURO SIN PARTO": "Trabajo de parto prematuro sin parto",
    "PERDIDA DE CONOCIMIENTO-SINCOPE": "Síncope",
    "ACCID.VASC.ENC.AGUDO-NO ESP.HEM.ISQUEM.": "ACV agudo no especificado",
    "INGESTA DE MEDICAMENTOS": "Ingesta de medicamentos",
    "NEFRITIS TUBULOINTERSTICIAL AGUDA": "Nefritis aguda",
    "NEFRITIS TUBULOINT.NO ESPEC.AGUDA O CRON": "Nefritis no especificada",
    "COLECISTITIS": "Colecistitis",
    "CALC.CONDUCT.BILIAR S/COLANGITIS NI COLE": "Cálculos biliares sin complicaciones",
    "OTROS TRAS.DIENTES Y ESTRUC. DE SOSTEN": "Trastornos dentales no especificados",
    "HIPERGLICEMIA NO ESPECIFICADA": "Hiperglucemia no especificada",
    "BRONQUIOLITIS AGUDA": "Bronquiolitis aguda",
    "HISTORIA PERSONAL DE LESIÛN AUTOINFLIGID": "Antecedente de lesión autoinfligida",
    "MAREOS Y VERTIGO": "Mareos y vértigo",
    "OTROS PROCEDIMIENTOS MÈDICOS": "Otros procedimientos médicos",
    "OTROS TRASTORNOS DEL SISTEMA URINARIO": "Trastornos urinarios no especificados",
    "PANCREATITIS AGUDA.": "Pancreatitis aguda",
    "FALSO TRABAJO DE PARTO S/ESPECIFICACION": "Falso trabajo de parto",
    "LUMBAGO NO ESPECIFICADO": "Lumbago no especificado",
    "TRAUMATISMO INTRACRANEAL": "Traumatismo intracraneal",
    "DIABETES MELLITUS NO INSULINODEPENDIENTE": "Diabetes tipo 2",
    "CONTAC.C/BEB,ALIM,GRAS,ACEIT P/COC.CALIE": "Contacto con alimentos calientes",
    "DOLOR EN MIEMBRO": "Dolor en extremidad",
    "BRONQUIOLITIS AGUDA, NO ESPECIFICADA": "Bronquiolitis no especificada",
    "OTROS PROCEDIMIENTOS QUIR˙RGICOS": "Otros procedimientos quirúrgicos",
    "EPISODIO DEPRESIVO NO ESPECIFICADO": "Episodio depresivo no especificado",
    "FRACTURA DEL ANTEBRAZO": "Fractura de antebrazo",
    "CONVULSIONES FEBRILES": "Convulsiones febriles",
    "ABDOMEN AGUDO": "Abdomen agudo",
    "SEGUIMIENTO POSTPARTO, DE RUTINA": "Control postparto",
    "HERIDA DE LA CABEZA": "Herida en la cabeza",
    "ENFERM.PULM.OBSTRUCTIV.CRONIC.NO ESPECIF": "EPOC no especificada",
    "INCOMPATIBILID.ABO DEL FETO Y REC.NACID.": "Incompatibilidad ABO neonatal",
    "FRACTURA A NIVEL DE LA MUÒECA Y DE MANO": "Fractura de muñeca o mano",
    "NEUMONIA BACT.NO CLASIF.EN OTRA PARTE": "Neumonía bacteriana",
    "AGRESION C/DISP.OTRS.ARMAS DE FUEGO": "Agresión con arma de fuego",
    "ANORMALIDADES DE LA RESPIRACION": "Alteraciones respiratorias",
    "OTRAS CONVULSIONES Y LAS NO CLASIFICADAS": "Convulsiones no especificadas",
    "ULCERA CRONICA DE PIEL NO CLAS.EN O.PART": "Úlcera crónica de piel",
    "GASTRITIS NO ESPECIFICADA": "Gastritis no especificada",
    "DIABETES MELLITUS INSULINODEPENDIENTE, C": "Diabetes tipo 1",
    "COLECISTITIS NO ESPECIFICADA": "Colecistitis",
    "INSUFICIENCIA CARDIACA CONGESTIVA": "Insuficiencia cardíaca congestiva",
    "DIFICULTAD RESP.DEL REC.NACID.NO ESPEC.": "Dificultad respiratoria neonatal",
    "INFECCIÛN LOCAL DE LA PIEL Y DEL TEJIDO": "Infección cutánea local",
    "MALESTAR Y FATIGA": "Malestar general y fatiga",
    "CAIDA NO ESPECIFICADA": "Caída no especificada",
    "ABORTO ESPONT·NEO, INCOMPLETO, SIN COMPL": "Aborto espontáneo incompleto",
    "DORSALGIA NO ESPECIFICADA": "Dorsalgia no especificada",
    "OBSERVACIÛN POR SOSPECHA DE OTRAS ENFERM": "Observación por sospecha de otras enfermedades",
    "HERIDA DE LA PIERNA, PARTE NO ESPECIFICA": "Herida de la pierna",           
    "ATENCIÛN Y EXAMEN INMEDIATAMENTE DESPUÈS DOLOR EN ARTICULACION ESTERILIZACIÛN": "Dolor en articulación",      
    "HERNIA INGUINAL": "Hernia Inguinal",              
    "CUERPO EXTRAÒO EN EL TUBO DIGESTIVO":"Cuerpo extraño en el tubo digestivo",
    "ENFERM.PULM.OBSTRUCT.CRONIC.C/EXACERBAC.": "EPOC con exacerbación",
    "OTROS SINTOMAS Y SIGNOS GENERALES": "Síntomas y signos generales no especificados",
    "CALC. VESIC. BILIAR SIN COLECISTITIS": "Cálculos biliares sin colecistitis",
    "HERIDA DE REGION NO ESPECIF.DEL CUERPO": "Herida",
    "PARTO PREMATURO SIN TRAB.DE PARTO ESPONT": "Parto prematuro sin trabajo de parto espontáneo",
    "DOLO EN EL PECHO NO ESPECIFICADO": "Dolor torácico no especificado",
    "ASCITIS": "Ascitis",
    "FALSO TRAB.DE PART.ANTES 37 SEMAN.COMPL.": "Falso trabajo de parto antes de las 37 semanas",
    "CELULITIS DE LA CARA": "Celulitis",
    "DIABETES MELLITUS QUE SE ORIG.EN EMBARAZ": "Diabetes gestacional",
    "INFECC.DEL RINON EN EL EMBARAZO": "Infección renal durante el embarazo",
    "FRACTURA DE MIEMBRO INFER.,NIVEL NO ESP.": "Fractura de miembro inferior no especificado",
    "FRACTURA DE LA PIERNA, INCLUSIVE TOBILLO": "Fractura de pierna o tobillo",
    "SIFILIS CONGENITA SIN OTRA ESPECIFICAC.": "Sífilis congénita no especificada",
    "HERN.INGUIN.UNILATER.NO ESP.S/OBST./GAN": "Hernia inguinal unilateral sin obstrucción ni gangrena",
    "FRACTURA DE LA PIERNA, PARTE NO ESPECIFI": "Fractura de pierna",
    "DIABETES MELLITUS, NO ESPECIFICADA, CON": "Diabetes mellitus no especificada con complicaciones",
    "INGESTA DE TOXICOS": "Intoxicación por sustancias",
    "RUPTURA PREMATURA DE LAS MEMBRANAS": "Ruptura prematura de membranas",
    "OTR.DROGAS Y SUST.BIOLOGIC.Y LAS NO ESPE": "Uso de drogas y sustancias biológicas no especificadas",
    "INFECC.NO ESPEC.DE VIAS URINAR.EN EL EMB": "Infección urinaria no especificada en el embarazo",
    "DIABETES MELLITUS NO ESPECIFICADA": "Diabetes mellitus no especificada",
    "OTROS TRAST.FUNCIONALES DEL INTESTINO": "Trastornos funcionales intestinales no especificados",
    "ANEMIA DE TIPO NO ESPECIFICADA": "Anemia no especificada",
    "ASMA": "Asma",
    "TOS":"Tos",
    "HEMATURIA":"Hematuria",                                            
    "BRONQIOLITIS AGUD.DEBID.A VIRUS SINCITAL":"Bronquiolitis",
    "ATENCIÛN Y EXAMEN INMEDIATAMENTE DESPUÈS": "Dolor en articulación",
    "FRACTURA DE OTRAS PARTES DE LA PIERNA": " Fractura de la pierna",
    "OTR.ENF.CEREBROVASCULARES ESPECIFICADAS": "Enfermedad cerebrovascular",
    "TRAUMATISMO INTRACRANEAL NO ESPECIFICADO":"Traumatismo intracraneal",
    "COLECISTITIS AGUDA":"Colecistitis",
    "ESTERILIZACIÛN_": "Esterilización",
    "ESTERILIZACIÛN": "Esterilización",
    "HERIDAS QUE AFECT.MULTIP.REGIO.DEL CUERP":"Herida",
    "OBSTRUCCION DEL CONDUCTO BILIAR":"Obstrucción del conducto biliar",
    "Fiebre no especificada":"Fiebre",
    "FRACTURA DE LA DI·FISIS DE LA TIBIA": "Fractura de la pierna",
    "PARTO CON CESAREA DE EMERGENCIA": "Parto con cesarea de emergencia",
    "Celulitis facial":"Celulitis",
    "DOLOR EN ARTICULACION" :"Dolor en articulación"        
                   
}

# %%
df_completo["diagnostico_ingreso"] = df_completo["diagnostico_ingreso"].replace(diccionario_normalizado)

# %%
print(df_completo["diagnostico_ingreso"].value_counts())
# Out:
# diagnostico_ingreso
# Anomalía dinámica del trabajo de parto                    5414
# COVID-19                                                  3985
# Dolor abdominal y pélvico                                 3979
# Parto único espontáneo                                    2974
# Otros dolores abdominales no especificados                1760
# Diarrea y gastroenteritis de origen infeccioso            1652
# Trabajo de parto prolongado                               1265
# Ruptura prematura de membranas                            1024
# Neumonía                                                   966
# Náuseas y vómitos                                          890
# Cesárea electiva                                           878
# Parto único por cesárea                                    868
# Fiebre                                                     857
# Celulitis                                                  854
# EPOC no especificada                                       829
# Convulsiones no clasificadas                               810
# Traumatismo craneal no especificado                        808
# Dolor torácico                                             779
# Apendicitis aguda                                          773
# Disnea                                                     752
# Traumatismos múltiples                                     737
# Cefalea                                                    650
# Infección urinaria no especificada                         636
# Cólico renal                                               634
# Recién nacidos prematuros                                  628
# Otros traumatismos craneales                               585
# Absceso dental sin fístula                                 553
# Colecistitis                                               526
# Crisis asmática                                            501
# Aborto médico                                              491
# Hipertensión materna                                       478
# Dolor abdominal en epigastrio                              467
# Dolor lumbar                                               467
# Ictericia neonatal                                         461
# Dolor precordial                                           339
# Fiebre no especificada                                     327
# Hipertensión esencial                                      326
# Síncope                                                    316
# ACV agudo no especificado                                  312
# Trabajo de parto prematuro sin parto                       308
# Ingesta de medicamentos                                    301
# Dolor en articulación                                      287
# Nefritis aguda                                             287
# Nefritis no especificada                                   283
# Traumatismo intracraneal                                   277
# Cálculos biliares sin complicaciones                       269
# Otros procedimientos médicos                               255
# Trastornos dentales no especificados                       246
# Hiperglucemia no especificada                              243
# Bronquiolitis aguda                                        239
# Antecedente de lesión autoinfligida                        239
# Mareos y vértigo                                           228
# Herida                                                     224
# Trastornos urinarios no especificados                      220
# Otros procedimientos quirúrgicos                           216
# Pancreatitis aguda                                         210
# Falso trabajo de parto                                     206
# Lumbago no especificado                                    203
# Dolor en extremidad                                        202
# Diabetes tipo 2                                            201
# Contacto con alimentos calientes                           197
# Bronquiolitis no especificada                              191
# Episodio depresivo no especificado                         190
# Convulsiones febriles                                      189
# Fractura de antebrazo                                      188
# Herida en la cabeza                                        185
# Abdomen agudo                                              183
# Control postparto                                          181
# Fractura de muñeca o mano                                  177
# Incompatibilidad ABO neonatal                              171
# Agresión con arma de fuego                                 169
# Neumonía bacteriana                                        169
# Malestar general y fatiga                                  165
# Convulsiones no especificadas                              162
# Alteraciones respiratorias                                 162
# Úlcera crónica de piel                                     161
# Diabetes tipo 1                                            155
# Gastritis no especificada                                  154
# Dificultad respiratoria neonatal                           153
# Caída no especificada                                      152
# Infección cutánea local                                    152
# Insuficiencia cardíaca congestiva                          151
# Observación por sospecha de otras enfermedades             148
# Aborto espontáneo incompleto                               146
# Herida de la pierna                                        146
# Dorsalgia no especificada                                  146
# Síntomas y signos generales no especificados               145
# Esterilización                                             134
# Hernia Inguinal                                            133
# Cuerpo extraño en el tubo digestivo                        130
# EPOC con exacerbación                                      129
# Ascitis                                                    127
# Dolor torácico no especificado                             126
# Cálculos biliares sin colecistitis                         125
# Parto prematuro sin trabajo de parto espontáneo            123
# Fractura de miembro inferior no especificado               123
# Falso trabajo de parto antes de las 37 semanas             121
# Fractura de pierna o tobillo                               119
# Infección renal durante el embarazo                        117
# Diabetes gestacional                                       117
# Sífilis congénita no especificada                          116
# Hernia inguinal unilateral sin obstrucción ni gangrena     114
# Fractura de pierna                                         112
# Uso de drogas y sustancias biológicas no especificadas     111
# Intoxicación por sustancias                                110
# Diabetes mellitus no especificada con complicaciones       110
# Anemia no especificada                                     109
# Hematuria                                                  107
# Tos                                                        105
# Trastornos funcionales intestinales no especificados       104
# Diabetes mellitus no especificada                          103
# Infección urinaria no especificada en el embarazo          103
# Asma                                                        99
# Bronquiolitis                                               98
# APENDICITIS AGUDA CON ABSCESO PERITONEAL                    97
# OTRS.SINT.Y SIGNOS DE SIST.NERV. Y OSTEO                    96
# INF.AG.VIAS RESP.SUP.SITIOS MULT.O NO ES                    96
# OTROS CUIDADOS POSTERIORES A LA CIRUGIA                     95
# EDEMA LOCALIZADO                                            94
# EPILEPSIA                                                   93
# OTRAS HEMORRAGIAS UTER O VAGIN ANORM                        93
# INFECC.CONSECUT.A PROCED.NO CLASIFICADA                     93
# OTRAS ENF.DEL SISTEMA DIGESTIVO                             92
# HERIDA DE PARED ABDOMINAL                                   90
# ENFERM.DE LA TRAQUEA Y BRONQUIOS N/CLAS                     88
# Fractura de la pierna                                       87
# TRAUM.DE REGIONES NO ESPECIF.DEL CUERPO                     87
# FRACTURA DE MIEMBRO SUPER.,NIVEL NO ESPE                    86
# PEQUENO PARA LA EDAD GESTACIONAL                            86
# DOLOR CERVICAL                                              86
# OBSERVACIÛN POR SOSPECHA DE TUBERCULOSIS                    85
# COLITIS Y GASTROENT.NO INFECC.NO ESPECIF                    84
# HERIDA DEL TORAX                                            84
# HIPERTROF.DE LAS AMIGD.CON HIPER.ADENOID                    82
# MOTOCICLISTA LES.x COL.c/AUTO-CAM-FUR.                      81
# FRACTURA DEL FEMUR                                          81
# SEPTICEMIA NO ESPECIFICADA                                  81
# OTR.AFECC.ESPEC.DE LOS DIENTES Y SUS EST                    81
# ULCERA DE MIEMBRO INF. NO CLAS.E/O/PARTE                    80
# OTROS CAMBIOS EN LA PIEL                                    80
# OTR.SINT.Y SIG.INVOLUC.SIST.NERV.OSTEMUS                    80
# OBSER.Y EVALUA.MEDIC.P/SOSPECH.ENF,AFECC                    79
# INFEC.AGUDA NO ESPEC.VIAS RESP.INFERIOR.                    79
# DEPLECION DE VOLUMEN                                        79
# DIABETES MELLITUS, NO ESPECIFICADA, SIN                     79
# BAJO PESO PARA LA EDAD GESTACIONAL                          78
# EMBARAZO ECTOPICO                                           78
# INFECC.AGUDA DE LAS VIAS RESP.SUPERIO.                      77
# INSUFICIENCIA CARDIACA                                      77
# NEUMONIA DEB.A ESTREPTOCOCOS DEL GRUPO B                    77
# INSUFICIENCIA RENAL NO ESPECIFICADA                         75
# MENSTRUACION EXCESIVA Y FREC.C/CICLO IRR                    75
# HERIDA DE LA MUÒECA Y DE LA MANO                            75
# ENTERORRAGIA                                                74
# ATENCIÛN POR PROCEDIMIENTO DE REHABILITA                    74
# FIBRILACION Y ALETEO AURICULAR                              74
# INSUFICIENCIA RESPIRATORIA AGUDA                            73
# AGRESION CON DISPARO DE ARMA CORTA                          73
# OTRAS ENF.PULMONARES OBSTRUCT. CRONICAS                     73
# O.TRAST.TEJIDO BLANDO ENF.CLAS.O.PARTE                      72
# INTOXICACION AGUDA x USO DE ALCOHOL                         72
# REACCION AL ESTRES GRAVE Y TRAST.DE ADAP                    72
# FRACTURA DE EPIFISIS INF. DEL HUMERO                        71
# MENSTRUACION EXCESIVA, FRECUENTE E IRREG                    71
# QUEMAD.Y CORROS.,REGION NO ESPECIFICADA                     71
# DESORIENTACION NO ESPECIFICADA                              70
# TAQUIPNEA TRANSITORIA DEL RECIEN NACIDO                     69
# EXAMEN Y ATENCION DEL POSTPARTO                             69
# TMyC DEBIDOS AL USO DE MULTIPLES DROGAS                     68
# PALPITACIONES                                               68
# PSICOSIS DE ORIG.NO ORGANICO, NO ESPECIF                    68
# INSUFICIENCIA RENAL AGUDA                                   68
# HEMORRAGIA ANTEPARTO NO ESPECIFICADO                        66
# PROCTORRAGIA                                                66
# ATENCION X USO DE PROCED.DE REHABILITAC.                    66
# AGRESION CON OBJETO CORTANTE                                65
# CONSTIPACION                                                65
# TRAST.DEL HIG.EN EL EMBARAZO PARTO PUERP                    64
# MORDEDURA O ATAQUE DE PERRO                                 64
# ENFERMEDAD INFLAMAT.DEL CUELLO UTERINO                      63
# EFECTOS DE LA CORRIENTE ELECTRICA                           63
# ABSCESO PERIAMIGDALINO.                                     63
# OTRAS ENF ESPECIF COMPLIC EMB, PAR Y PUE                    62
# NEUMONIA, ORGANISMO NO ESPECIFICADO                         62
# TRAUMATISMO NO ESPECIFICADO                                 62
# NEUMONIA BACTERIANA                                         61
# ENF. DE LA PULPA Y TEJIDOS PERIAPICALES                     61
# ABSCESO ANAL                                                61
# TRASTORNOS INFLAMATORIOS DE LA MAMA                         61
# PROBLEMAS RELACIONA.C/EL AMBIENTE SOCIAL                    61
# SEPSIS PUERPERAL                                            60
# HERIDA DE OTRAS PARTES DE LA CABEZA                         60
# ALTERACIÛN NO ESPECIFICADA DE LA REGULAC                    59
# TRASTORNOS DE ADAPTACION                                    59
# MIALGIAS                                                    59
# OTRAS INF.DE PIEL Y TEJIDO SUBCUTANEO.                      59
# APENDICITIS, NO ESPECIFICADA.                               58
# DOLOR TESTICULAR                                            58
# LINFADENITIS AGUDA SITIO NO ESPECIFICADO                    57
# APENDICITIS AGUDA CON PERITONITIS GENERA                    57
# DOLOR DE GARGANTA Y EN EL PECHO                             56
# HERNIA UMBILICAL                                            56
# OTROS TRAST.DEL PULMON                                      55
# ESTADO DE ABSTINENCIA x USO DE ALCOHOL                      55
# RETENCION DE ORINA                                          55
# OTROS TRAUMAT.DE LA CABEZA ESPECIFICADOS                    55
# HEMORROIDES                                                 55
# CONTROL POST-OPERATORIO                                     55
# ICTERICIA NO ESPECIFICADA                                   54
# ILEO NO ESPECIFICADO                                        53
# OTRAS ANEMIAS                                               53
# TRAST.X CORTA GESTAC.BAJO PESO AL NACER                     53
# TUMOR MALIGNO DE LA MAMA                                    53
# PREECLAMPSIA NO ESPECIFICADA                                53
# PREPUCIO REDUNDANTE,FIMOSIS, PARAFIMOSIS                    53
# REHABILITACIÛN DEL DROGADICTO                               53
# ANORM.DE LA DINAMICA  DEL TRAB.DE PARTO                     52
# ABSCESO CUTANEO, FURUNCULO Y CARBUNCO                       52
# QUEMAD.CADER.MIEMB.INF.2DO GRAD.S/TOB.PI                    52
# ENFERM.DE VIAS RESP.SUPERIOR.NO ESPECIF.                    52
# INSUFICIENCIA RENAL CRONICA                                 52
# HEMORRAGIA VAG.Y UTERINA ANORMAL NO ESPE                    52
# Parto con cesarea de emergencia                             51
# MASA NO ESPECIFICADA EN LA MAMA                             51
# EDEMAS                                                      51
# INSUFICIENCIA RESPIRATORIA NO ESPECIFICA                    51
# DERRAME PLEURAL NO CLASIF. EN O. PARTE.                     51
# ASFIXIA DEL NACIMIENTO LEVE Y MODERADA                      50
# ABORTO ESPONT·NEO, INCOMPLETO, COMPLICAD                    48
# ABSCESO CUTANEO FURUNC.CARBUNCO NO ESPEC                    47
# ENFERMEDADES DE LA GLANDULA DE BARTHOLIN                    47
# QUEMAD.MULTIP.REGION.MENCION.NO MAS 2DO                     46
# LINFADENITIS INESPECIFICA NO ESPECIFICAD                    45
# CELULITIS SITIO NO ESPECIFICADO                             45
# DOLOR DE GARGANTA                                           45
# DIABETES MELLITUS INSULINODEPENDIENTE                       45
# TORSION DEL TESTICULO                                       45
# FRACTURA DEL HOMBRO Y DEL BRAZO                             44
# ATENC.MATERN.X DEFICIT DEL CRECIM.FETAL                     44
# TRABAJO DE PARTO PROLONGADO                                 44
# FARINGITIS AGUDA NO ESPECIFICADA                            43
# HIPOGLICEMIA NO ESPECIFICADA                                43
# Enfermedad cerebrovascular                                  43
# PREECLAMPSIA SEVERA                                         43
# OTROS TRASTOR. RESPIRATORIOS.                               42
# CONTACTO CON BEBIDAS, ALIMENTOS, GRASAS                     42
# HERIDA DEL ABDOMEN,REGION LUMBOSA,PELVIS                    42
# QUEMAD.CABEZA CUELLO DE 2DO GRADO                           42
# ERISIPELA                                                   42
# ENCEFALOPATIA NO ESPECIFICADA                               42
# HEMATEMESIS                                                 41
# OTRAS HEMORRAGIAS GASTROINTESTINALES                        41
# NEUMONIA DEBIDA A VIRUS SINCITAL RESPIR.                    40
# HALLAZG.ULTRASONIC.ANORM.EN EXAM.PRENATA                    40
# DOLOR AGUDO                                                 40
# HERIDA DEL TOBILLO Y DEL PIE                                40
# EXAM.PESQUISA ESPEC.P/ENF.INFEC Y PARASI                    40
# OTRAS HIPOGLICEM.NEONATALES                                 40
#  Fractura de la pierna                                      40
# DIFICULTAD RESPIRATORIA DEL RECIEN NACI.                    39
# ASFIXIA DEL NACIMIENTO NO ESPECIFICADA                      39
# COLELITIASIS                                                39
# ABSCESO DE LAS REGIONES ANAL Y RECTAL.                      39
# DISURIA                                                     39
# URTICARIA, NO ESPECIFICADA                                  39
# NEUMOTORAX                                                  39
# USO NOCIVO MULTIPLES DROGAS Y SUST PSICO                    38
# TRASTORNO SISTEMA URINARIO NO ESPECIFICA                    38
# PROBLEMA NO ESPECIFICADO RELACIONADO CON                    38
# HERIDA DE OTRAS PARTES DE LA PIERNA                         38
# OTRAS ENFERMED.PELVICAS INFLAM.FEMENINAS                    37
# APORREO, GOLPE, MORDEDURA, PATADA, RASGU                    37
# CALC. VESIC. BILIAR CON COLECISTITIS AGU                    37
# NEUMONITIS DEBID.A ASPIRAC.DE ALIMENTO                      37
# URTICARIA                                                   37
# HERIDAS MULTIPLES NO ESPECIFICADAS                          36
# DIABETES MELLITUS ESPECIFICADA, CON CETO                    36
# DISFAGIA                                                    36
# HERIDA DE LA RODILLA                                        35
# OTRS.SINT.Y SIGNOS DE SIST.DIGEST Y ABDO                    35
# OTROS PROBLEMAS DE ALIMENTACIÛN DEL RECI                    35
# HERIDA DE LA CADERA                                         35
# BRONQUITIS,NO ESPEC.COMO AGUDA O CRONICA                    35
# HEMIPLEJIA NO ESPECIFICADA                                  35
# SINT.Y SIGN.CONCERN.A ALIM.E INGEST.LIQU                    34
# EDEMA ANGIONEUROTICO                                        34
# HEMORRAGIAS DE LAS VIAS RESPIRATORIAS                       34
# EMBOLIA Y TROMBOSIS VENA NO ESPECIFICADA                    34
# OTROS SINTOMAS Y SIGNOS GENERALES ESPE.                     34
# DOLOR NO ESPECIFICADO                                       33
# ABORTO ESPONT·NEO, COMPLETO O NO ESPECIF                    33
# ABSCESO CUTANEO FURUNC.CARBUNCO MIEMBRO                     33
# OTROS EX·MENES ESPECIALES ESPECIFICADOS                     33
# REACCION VIVENCIAL ANOMALA                                  33
# DISARTRIA Y ANARTRIA                                        33
# O.TRAS.PIEL,TEJ.SUBC.NO CLASIF.E/O/PARTE                    33
# ICTERICIA NEONATAL ASOC.C/PART.ANTES TER                    33
# INFARTO CEREBRAL                                            33
# CATETERIZACIÛN URINARIA                                     33
# TESTICULO NO DESCENDIDO UNILATERAL                          33
# CHOQUE ANAFILACTICO NO ESPECIFICADO                         33
# ESCABIOSIS                                                  33
# INSUFICIENCIA RESP.NO CLAS.EN O.PARTE.                      33
# INFECCION BACTERIANA NO ESPECIFICADA                        32
# OT.TRAST.ARTIC.NO CLASIF.EN OTRA PARTE                      32
# ASMA NO ESPECIFICADO                                        32
# TRAUMATISMO DE LA PIERNA, NO ESPECIFICAD                    32
# HEMORRAGIA, NO CLASIFICADA EN OTRA PARTE                    32
# HERIDA DE LA MUÒECA Y DE LA MANO, PARTE                     32
# LARINGITIS AGUDA                                            31
# HIPOPOTASEMIA                                               31
# TRAUMAT.SUPERF.DE REGION NO ESPEC.CUERPO                    31
# OSTEOCONDROPATIA NO ESPECIFICADA                            31
# TAQUICARDIA NO ESPECIFICADA                                 31
# NEUMONIA DEBIDA A MYCOPLASMA PNEUMONIAE                     31
# OTRAS ENF. DE LA VESICULA BILIAL                            31
# TRAST.MENTAL.ORG.O SINT., NO ESPECIFIC.                     31
# INSUFICIENCIA RENAL AGUDA NO ESPECIFICAD                    31
# OSTEOMIELITIS                                               31
# FRACTURA DEL ANTEBRAZO, PARTE NO ESPECIF                    30
# EFECTOS DE OTRAS CAUSAS EXTERNAS                            30
# AGRESION CON DISPARO DE OTRAS ARMAS DE F                    30
# ATENC.MATERN.X MUERTE INTRAUTERINA                          30
# HERIDA DEL TOBILLO                                          30
# FRACTURA DE DIAFISIS DEL HUMERO                             30
# CAIDA EN MISMO NIV.X DESPL,TROPEZ,TRASPI                    29
# INMATURIDAD EXTREMA                                         29
# INFECCION DE HERIDA QUIRURGICA OBSTETRIC                    29
# HERIDA DEL BRAZO                                            29
# TUM.COMP.INC.OTROS ORGANOS GEN.FEMENINOS                    29
# OTRAS ALTERACIONES CEREBRALES ESPECIFICA                    29
# OTRAS ATENCIONES MÈDICAS ESPECIFICADAS                      28
# EFECT.TOXI.DEL CONTACTO C/ANIMALES VENEN                    28
# TRAUMAT.NO ESPEC.MIEMB.INFER.NIV.NO ESPE                    28
# OTROS ESTADOS POSTQUIRURGICOS                               28
# QUEMAD.HOMB.MIEMB.SUP.DE 2DO GRAD.                          27
# OTR.ANORM.RESPIRACION Y LAS NO ESPECIFIC                    27
# CALCULO DEL RIÒON                                           27
# EDEMA PULMONAR                                              27
# HERIDA DE DEDO(S) DE LA MANO, SIN DAÒO D                    27
# ESPINA BIFIDA LIMBAR C/HIDROCEFALO                          27
# MIALGIA                                                     27
# FRACTURA DE LA BOVEDA DEL CRANEO                            27
# SINUSITIS CRONICA NO ESPECIFICADA                           27
# IMPETIGO                                                    27
# EXTIRP DE TUMORES, QUISTES O HIPERPL GRA                    27
# ANQUILOGLOSIA                                               26
# FIEBRE PERSISTENTE                                          26
# INESTABILIDAD EN LA MARCHA                                  26
# SECUEL.DE ENF.INFLAM.DEL SIST.NERV.CENT.                    26
# TUMOR BENIGNO DEL ˙TERO, PARTE NO ESPECI                    26
# TUBERCUL.RESPIRAT. NO CONFIRM.BACT HISTO                    26
# TRAUMAT.VASOS SANG.DE LA CABEZA NO CLASI                    25
# FLATULENCIA Y AFECCIONES AFINES                             25
# HERIDAS M˙LTIPLES DE LA PIERNA                              25
# TETRALOGIA DE FALLOT                                        25
# HIDROCELE NO ESPECIFICADO                                   25
# QUEMADURA DEL TRONCO DE 2DO GRADO                           25
# PROLONGAC.DEL PRIMER PERIODO                                25
# DEFECTO DEL TABIQUE AURICULAR                               25
# EFECTO TOXICO DE MONOXIDO DE CARBONO                        25
# TRASTORNO DE ANSIEDAD NO ESPECIFICADO                       25
# GASTROENTERITIS Y COLITIS DE ORIGEN S/E                     24
# DOLOR LOC.EN OT.PARTES INF.DEL ABDOMEN                      24
# ENFERM.DEL REFLUJO GASTROESOFAGICO S/ESO                    24
# EXAMEN DE PESQUISA ESPECIAL PARA OTRAS E                    24
# TUBERCULOSIS RESP.CONFIRM.BACTER.E HISTO                    24
# HERIDA DE OTRAS PARTES DEL PIE                              24
# COMPLICAC.RELAC.CON EMBARAZO NO ESPECIFI                    24
# ATENCIÛN PALIATIVA                                          24
# QUEMADURA Y CORROSION DE CABEZA Y CUELLO                    24
# FRACTURA DE LA COLUMNA LUMBAR Y PELVIS                      24
# CARIES DENTAL NO ESPECIFICADA                               23
# MIOSITIS INFECCIOSA                                         23
# PROLAPSO GENITAL FEMENINO                                   23
# CUERP.EXTRAN.TUBO DIGEST.PART.NO ESPEC.                     23
# HERIDA SUPERFICIAL DE LA PIERNA                             23
# HERIDAS OTRAS PART.Y NO ESP.DEL ABDOMEN                     23
# ABORTO ESPONTANEO                                           23
# EPILEPSIA TIPO NO ESPECIFICADO                              23
# HERIDA DEL MUSLO                                            23
# HERNIA UMBILICAL S/OBSTRUC.C/GANGRENA                       23
# LUMBAGO CON CIATICA                                         23
# ANOREXIA NERVIOSA                                           23
# EXAMEN MÈDICO GENERAL                                       23
# ABSCESO CUTANEO FURUNC.CARBUNC OTR.SITIO                    22
# OTROS VERTIGOS PERIFERICOS                                  22
# INVAGINACION                                                22
# USO NOCIVO DE ALCOHOL                                       22
# ATRESIA DEL ESOFAGO S/MENCION DE FISTULA                    22
# FRACTURA DE LA CLAVICULA                                    22
# PARTO MULTIPLE TODOS POR CESAREA                            22
# OTRS.TRAUMAT.Y LOS NO ESPEC.DE MUÒE,MANO                    22
# TRAUMATISMO NO ESPECIFICADO DE LA MUÒECA                    22
# INFARTO AGUDO DEL MIOCARDIO                                 22
# TUBERCUL. DEL PULMON CONFIR.POR HALLAZGO                    22
# ATENCIÛN MÈDICA, NO ESPECIFICADA                            22
# QUISTE DEL COLEDOCO                                         22
# QUEMADURA DE MUÒECA Y MANO DE 2DO GRADO                     22
# FRACTURA DEL PIE, NO ESPECIFICADA                           22
# SINDROME NEFROTICO                                          22
# OTRAS ENFERMEDADES CEREBROVASCULARES                        22
# NIVEL ELEVADO DE GLUCOSA EN LA SANGRE.                      21
# ABUSO SEXUAL                                                21
# NEUMONITIS DEB.A SOLIDOS Y LIQUIDOS.                        21
# ADENOMEGALIA                                                21
# TRASTORNO DEL S.N.C. NO ESPECIFICADO                        21
# DOLOR PELVICO Y PERINEAL                                    21
# RECIEN NACIDO EXCEPCIONALMENTE GRANDE                       21
# MIASIS                                                      21
# CATETERIZACIÛN CARDÌACA                                     21
# MALFORMACION CONGENITA DEL CORAZON N/ESP                    21
# TRAUMAT.SUPERFICIAL DE LA MUÒECA Y MANO                     21
# TESTICULO NO DESCENDIDO S/OTRA ESPECIFIC                    21
# Obstrucción del conducto biliar                             21
# ARTRITIS PIOGENA NO ESPECIFICADA                            21
# CAUSAS DE MORBILIDAD DESCONOC. Y NO ESP.                    21
# NEUMONIA VIRAL, NO CLASIF.EN OTRA PARTE                     20
# QUEMADURA TOBILLO PIE DE 2DO GRADO                          20
# HEPATITIS ALCOHOLICA                                        20
# QUEMA.Y CORROS.DE CADER. Y MIEMBR.INFER.                    20
# FRACTURA CRANEO-HUESOS DE CARA NO ESPECI                    20
# DERMATITIS NO ESPECIFICADA                                  20
# ESTRABISMO NO ESPECIFICADO                                  20
# PARO CARDIACO                                               20
# ALERGIA NO ESPECIFICADO                                     20
# EPILEP.Y SINDR.EPILEPT.IDIOPAT.GENERALIZ                    20
# DIABETES MELLITUS EN EL EMBARAZO                            20
# FISTULA ARTERIOVENOSA ADQUIRIDA                             20
# POLICITEMIA NEONATAL                                        20
# VENENO DE ESCORPION                                         20
# OTROS CAMBIOS DE PIEL Y LOS NO ESPECIF                      20
# DIABETES INSIPIDA                                           20
# HEMORRAGIA PRECOZ DEL EMBARAZ.S/ESPEC.                      20
# HERIDA DEL CUERO CABELLUDO                                  20
# TRAUMATISMO CEREBRAL DIFUSO                                 20
# TRAUMATISMO DEL PIE Y DEL TOBILLO, NO ES                    20
# AGRANULOCITOSIS                                             20
# CELULITIS DEL TRONCO                                        20
# FRACTURA DEL MAXILAR INFERIOR                               19
# FRACTURA DEL PIE, EXCEPTO DEL TOBILLO                       19
# ENFERMEDAD TOXICA DEL HIGADO                                19
# FARINGITIS AGUDA                                            19
# OTRS.TRAUM.Y LOS NO ESP.DE PIE Y TOBILLO                    19
# TRASTORNO DE PIEL Y TEJ.SUBC.NO ESPECIFI                    19
# HERIDA DE LA CABEZA PARTE NO ESPECIFICAD                    19
# ANGINA DE PECHO C/ESPASMO DOCUMENTADO                       19
# TMyC DEBIDOS AL USO DE ALCOHOL                              19
# OTR.INFECC.AGUD.DE SITIOS MULTIP.VIAS RE                    19
# ATAQUE CIANOTICO DEL RECIEN NACIDO                          19
# HERPES ZOSTER SIN COMPLICACIONES                            19
# FRACTURA DE OTRO DEDO DE LA MANO                            19
# LESION AUTOINF INTENC X AHORCAMIENTO                        19
# HEMOPTISIS                                                  19
# INFARTO AGUDO MIOCARDIO S/OTRA ESPECIFIC                    19
# ANEMIA DEF.HIERRO S/OTRA ESPECIFICACION                     19
# MELENA                                                      19
# BRONQUITIS AGUDA NO ESPECIFICADA                            19
# CUERPO EXTRANO EN EL ESOFAGO                                19
# EDEMA NO ESPECIFICADO                                       18
# FRACTURA DEL CUELLO DE FÈMUR                                18
# DESPREND.PREMAT.DE PLACENT.S/ESPECIFIC                      18
# OTRAS HEM.INTRACRANEALES NO TRAUMATICAS                     18
# LEIOMIOMA DEL UTERO                                         18
# PIELONEFRITIS CRONICA OBSTRUCTIVA                           18
# HERIDA DEL ANTEBRAZO, PARTE NO ESPECIFIC                    18
# EPISTAXIS                                                   18
# ARTRITIS NO ESPECIFICADA                                    18
# OTR.INFEC.LOC.ESP.PIEL Y TEJ.SUBCUTANEO                     18
# SINTOMAS URINARIOS BAJOS                                    18
# VOMITOS DEL EMBARAZO NO ESPECIFICADOS                       18
# FRACTURA DEL FÈMUR, PARTE NO ESPECIFICAD                    18
# LEUCEMIA LINFOLASTICA AGUDA                                 18
# OSTEOGENESIS IMPERFECTA                                     18
# FRACTURA DE LA RÛTULA                                       18
# COMPLI.DISPOS.PROTE,IMPLA,INJER.ORTOPED                     18
# DEFECTO DEL TABIQUE VENRICULAR                              18
# ORQUITIS EPIDIDIMITIS-ORQUIEPIDID.S/ABSC                    18
# LESION AUTOINF INTENC X OBJETO CORTANTE                     18
# OTR.ANORM.DE MARCHA Y MOVILID.Y NO ESPEC                    18
# INSUFICIENCIA CARDIACA NO ESPECIFICADA                      17
# FRACTURA DEL PERONÈ SOLAMENTE                               17
# ENFERMEDAD DE HIRSCHSPRUNG                                  17
# TRAST.DEL METAB.DEL CALCIO                                  17
# TRAUMATISMOS NO ESPECIFICADOS DEL HOMBRO                    17
# OTRAS EPILEP.Y SINDROMES EPILEPTIC.GENER                    17
# ICTERIC.NEONAT.X OTRAS CAUSAS Y X NO ESP                    17
# ESGUINCES Y TORCEDURAS DEL TOBILLO                          17
# COCAINA                                                     17
# RUPTURA PREMAT.DE MEMBRAN.E INIC.PARTO                      17
# MOTOC.LES.x COL.c/VEH.MOTOR 2-3 RUEDAS                      17
# HIPOGLICEMIA NEONATAL YATROGENICA                           17
# ABSCESO CUTANEO FURUNC.CARBUNCO OTR.SITO                    17
# HERNIA INGUINAL BILAT.S/OBSTRUCC.NI GANG                    17
# SINDROMES DEL MALTRATO                                      17
# OTRS.SINTO.Y SIGNOS CONCIEN.Y FUNC.COGNO                    17
# HEMORRAGIA INTRAENCEFALICA                                  17
# OTROS TIPOS DE APENDICITIS                                  17
# EFECTO TOXICO DEL ALCOHOL                                   17
# HERIDA DE OTRAS PARTES DEL TORAX                            17
# CEFALEA DEBIDA A TENSION                                    17
# TORSION OV.PEDICULO DE OV.Y TROMP.FALOP.                    17
# OTROS QUIST.OVARICOS Y LOS NO ESPECIFICA                    17
# RETARDO DEL CRECIMIENTO FETAL NO ESPECIF                    17
# OTR.ENFERM.DEGENERAT.ESPECIFIC.DE NUCLEO                    17
# ABSCESO CUTANEO FURUNC.CARBUNCO TRONCO                      17
# MIGRAÒA                                                     17
# TRAST.PSICOTICOS AGUDOS Y TRANSITORIOS                      17
# LUXACION ARTICULACION DEL HOMBRO                            17
# VOMITOS EXCESIVOS DEL EMBARAZO                              16
# OTROS DOLORES EN EL PECHO                                   16
# OTRAS ARRITMIAS CARDIACAS                                   16
# ENFERM.DIVERT.DEL INTEST.PARTE NO ESP.CO                    16
# SECUEL.DE OTRAS ENFER.INFECC.Y PARASITAR                    16
# ATAXIA NO ESPECIFICADA                                      16
# ABORTO NO ESPECIFICADO, COMPLETO O NO ES                    16
# HIPERT.GEST.(IND.X EMB) C/PROTEIN.SIGNIF                    16
# LINFADENITIS MESENTERICA INESPECIFICA                       16
# LINFADENITIS AGUDA                                          16
# INF.VIR.NOESPEC.CARACT.POR LESIO.DE PIEL                    16
# OTITIS EXTERNA                                              16
# FRACTURA DE OTRAS PARTES DEL ANTEBRAZO                      16
# NEUMONIA DEBIDA A OTROS VIRUS                               16
# HIPERTROFIA DE LAS AMIGDALAS                                16
# ENCEFALIT.MIELITIS Y ENCEFALOMIEL.S/ESP.                    16
# HERIDA REGION LUMBOSACRA Y PELVIS                           16
# OTRAS DEFORM. CONGENITAS DE LOS PIES                        16
# HIPOTENSION                                                 16
# CHOQUE SEPTICO                                              16
# OTROS SINTOMAS Y SIGNOS DEL SIST.URINAR.                    16
# QUEMADURA Y CORROSION DEL TRONCO                            15
# EMBOLIA Y TROMBOSIS OTR.VENAS ESPECIFICA                    15
# OTROS TRAUMATISMOS INTRACRANEALES                           15
# COARTACION DE LA AORTA                                      15
# HERIDA DEL TORAX PARTE NO ESPECIFICADA                      15
# PROCEDIMIENTO MÈDICO NO ESPECIFICADO                        15
# OTROS ESTADOS POSTQUIR˙RGICOS ESPECIFICA                    15
# TUMOR MALIGNO EL ENDDOCERVIX                                15
# O.TRAST.ESPEC.ORGANOS GENITALES MASCULIN                    15
# DESHIDRATAC.DEL REC.NACIDO                                  15
# TRASTORNOS DE LA CONDUCTA                                   15
# TUMOR MALIGNO DEL ENCEFALO                                  15
# ALTERACIONES DEL HABLA, NO ESPECIFICADAS                    15
# ANEMIA APLASTICA SIN OTRA ESPECIFICACION                    15
# TUBERC.RESPIR.NO ESPEC.SIN MENC.DE CONF.                    15
# HERNIA NO ESPEC. DE LA CAVIDAD ABDOMINAL                    15
# ESTADO DE EMBARAZO, INCIDENTAL                              15
# ENFERMEDAD INFLAMATORIA PELV.FEM.NO ESPE                    15
# QUEMAD.REGION CUERPO Y GRADO NO ESPECIF.                    15
# AFECCIÛN NO ESPECIFICADA DE LA PIEL, PRO                    15
# OTROS TRASTORNOS DE LA MAMA                                 15
# HEMIPLEJIA                                                  15
# MIOSITIS                                                    15
# INFECC.BACTER.DE SITIO NO ESPECIFICADO                      15
# OTRO TRAUMAT.MEDULA ESPINAL LUMBAR                          15
# SHIGELOSIS DE TIPO NO ESPECIFICADO                          15
# SEC.ENF.CEREBROVASC.NO ESP.C/HEM.U OCLUS                    15
# OTRAS APNEAS DEL RECIEN NACIDO                              15
# DISENTERIA AMEBIANA                                         15
# FRACTURA HOMBRO,BRAZO PARTE NO ESPECIFIC                    15
# ATENC.MATERN.X INCOMPETENC.DEL CUELLO UT                    15
# DEISCENCIA DE SUTURA DE CESAREA                             15
# AHORCAMIENTO, ESTRANGULAMIENTO Y SOFOCAC                    14
# OTRA ATENCION MEDICA                                        14
# INSUFICIENCIA HEPATICA NO ESPECIFICADA                      14
# FRACTURA DE OTRAS PARTES Y DE LAS NO ESP                    14
# TRASTORNO DE PANICO                                         14
# COMPLIC.DE PROCEDIM.,NO CLASIF.EN OTRA P                    14
# NEUMONÌA CONGÈNITA DEBIDA A OTROS AGENTE                    14
# SENILIDAD                                                   14
# MALABSORCION DEBID.A INTOLERANC.NO CLASI                    14
# TRAST. FUNCION VESTIBULAR NO ESPECIFICAD                    14
# FRACTURA DE LA EPÌFISIS SUPERIOR DEL C˙B                    14
# ABORTO NO ESPECIFICADO                                      14
# TAQUICARDIA PAROXISTICA                                     14
# TMyC DEBIDOS AL USO DE COCAINA                              14
# OTRAS AFECCIONES ERITEMATOSAS.                              14
# OTRS.TRAUM.MIEMBRO INFER.,NIVEL NO ESPEC                    14
# ENF. DIVERTICULAR DEL INTESTINO.                            14
# DELIRIO NO SUPERPU.A UN CUADRO DE DEMEN.                    14
# EMBARAZO ECTOPICO NO ESPECIFICADO                           14
# OTROS TRASTORNOS DE ANSIEDAD                                14
# TRAST.DE LOS MOVIMIENTOS ESTEREOTIPADOS                     14
# HERIDA DE CUELLO PARTE NO ESPECIFICADA                      14
# ACCIDENTE DE TRANSITO DE TIPO ESPECIFICA                    14
# HERIDA DE MIENB.SUP.NIV.NO ESPECIFICADO                     14
# PURPURA TROMBOCITOPENICA IDIOPATICA                         14
# ABSCESO CUTANEO FURUNCULO-CARBUNCO CARA                     14
# LUXACIÛN DEL CODO, NO ESPECIFICADA                          14
# HERIDA DE LA CADERA Y DEL MUSLO                             14
# ADENOMEGALIA NO ESPECIFICADA                                13
# TUBERC.RESPIRAT.NO ESPEC.CONF.BACTER/HIS                    13
# TROMBOCITOPENIA NO ESPECIFICADA                             13
# PARO CARDIACO NO ESPECIFICADO                               13
# DEFECTO DEL TABIQUE AORTOPULMONAR                           13
# HIPOSMOLARIDAD E HIPONATREMIA                               13
# FRACTURA DE LA DI·FISIS DEL FÈMUR                           13
# HEMORRAGIA SUBDURAL TRAUMATICA                              13
# DIARREA FUNCIONAL                                           13
# BRONQUIOLIT.AGUD.DEBIDA A OTR.MICROORG.                     13
# LARINGITIS Y TRAQUEITIS AGUDAS                              13
# OTITIS MEDIA NO ESPECIFICADA                                13
# SIND.MALF.CONG.AFEC.PRINCIP.APARIEN.FACI                    13
# INSUFICIENCIA RENAL CRONICA NO ESPECIFIC                    13
# CELULITIS DE OTROS SITIOS                                   13
# PERITONITIS                                                 13
# EXPOSI.A FUEGO NO CTRLADO EN EDIF, CONTR                    13
# AUS.ATRESIA Y ESTEN.CONG.ANO SIN FISTULA                    13
# OTROS CUIDADOS ESPECIFICADOS POSTERIORES                    13
# GANGRENA, NO CLASIFICADA EN OTRA PARTE                      13
# QUEMADURA DEL TRONCO GRADO NO ESPECIF.                      13
# CUIDADOS RELATIVOS AL PROCED.DE DIALISIS                    13
# NEUMOTORAX NO ESPECIFICADO                                  13
# ENFERMEDAD CELIACA                                          13
# DESNUT.PROTEICOCA.,NO ESPECIFICADA                          13
# SME DE DEPEND DEBIDO AL USO DE COCAINA                      13
# TRASTORNO INTERNO DE LA RODILLA                             13
# TUMEFACCION MASA-PROMINENCIA LOC. CUELLO                    13
# ANEURISMA CEREBRAL SIN RUPTURA                              13
# HERIDA VAGINA Y VULVA                                       13
# EXPOSICION A CTE.ELECTR.NO ESPECIFICADA                     13
# SUPERVISION DEL EMBARAZO NORMAL                             13
# PROBLEMAS RELACIONADOS CON LA FALTA DE V                    12
# TUBERC.PULMON SIN MENCION DE CONF.BACT/H                    12
# TUMEFACCION MASA O PROMINEN.INTRAAB.PELV                    12
# ASFIXIA DEL NACIMIENTO SEVERA                               12
# EFECT.ADVERSO NO ESPECIF.DE DROG.O MEDIC                    12
# PURPURA Y OTRAS AFECCIONES HEMORRAGICAS                     12
# MIASIS NO ESPECIFICADA                                      12
# TRAUMA. SUPERFICIAL DEL ANTEBRAZO Y CODO                    12
# CONTRACCIONES PRIMARIAS INADECUADAS                         12
# BENZODIAZEPINAS                                             12
# TRAUMATISMO SUPERFICIAL DE LA CABEZA                        12
# OSTEOMIELITIS NO ESPECIFICADA                               12
# COMPLICAC.MECAN.DE PROTESIS ARTIC.INTERN                    12
# HIPERGLICERIDEMIA PURA                                      12
# HERIDA DE OTRAS PARTES Y DE LAS NO ESPEC                    12
# PERDIDA ANORMAL DE PESO                                     12
# VOMITOS DEL RECIEN NACIDO                                   12
# HIDROCEFALO CONGENITO NO ESPECIFICADO                       12
# EMBARAZO DOBLE                                              12
# ALTERACIÛN CEREBRAL NO ESPECIFICADA DEL                     12
# TRASTORNOS INFLAMATORIOS DEL ESCROTO                        12
# OTRAS SEPTICEMIAS                                           12
# PARO CARDIACO C/RESUCUTACION EXITOSA                        12
# TUMOR MALIGNO DEL COLON                                     12
# SINDROME DEL MALTRATO NO ESPECIFICADO                       12
# SME DE DEPEND x USO DE CANNABINOIDES                        11
# O.MALFORM.CONGENITAS DEL CORAZON ESPEC.                     11
# CELULITIS DEDOS DE MANO Y PIE                               11
# FRACTURA DE LA DI·FISIS DEL C˙BITO Y DEL                    11
# TUBERC.DEL PULMON HALLADA POR CULTIVO                       11
# CHOQUE ANAFILACTICO DEB.REACC.ADVERSA AL                    11
# ARRITMIA CARDIACA NO ESPECIFICADA                           11
# LITIASIS URINARIA EN ESQUISTOSOMIASIS                       11
# AFECCION RESPIRAT.NO ESPEC.DEL REC.NACID                    11
# NEUMONMIA VIRAL NO ESPECIFICADA                             11
# COMPLICAC.MECANIC.DE DERIVAC.VENTRIC.INT                    11
# OTRAS PURPURAS NO TROMBOCITOPENICAS                         11
# AMENAZA DE ABORTO                                           11
# SINDROME DE DOWN NO ESPECIFICADO                            11
# ENFERM.INFLAMATORIA DEL HIGADO NO ESPEC.                    11
# CARCINOMA IN SITU DEL ENDOCERVIX                            11
# HEMORRAGIA PRECOZ DEL EMBARAZO                              11
# FRACTURA DE HUESOS DEL CRANEO Y LA CARA                     11
# PURPURA ALERGICA                                            11
# INFECCION VIRAL NO ESPECIFICADA                             11
# CONTACTO TRAUMATICO CON ESCORPION                           11
# SALPULLIDO Y OTRAS ERUPCIONES CUTANEAS                      11
# FLEB.TROMBOFLE.OTR.VAS.PROF.MIEMB.INFER                     11
# HIPERT.GEST.(IND.X EMB) S/PROTEIN.SIGNIF                    11
# OT.GASTROENT.Y COLITIS S/E DE ORIG.INFEC                    11
# ATRESIA DEL ESOF.C/FIST.TRAQUEOSOFAGICA                     11
# ABORTO MÈDICO, INCOMPLETO, SIN COMPLICAC                    11
# MALFORM.CONG. DE OTRAS GLAND.ENDOCRINAS                     11
# OTRS.TRAUM.NIVEL SUPERIOR,NIVEL NO ESPEC                    11
# MALFORMACION CONG. DEL INTEST. NO ESPECI                    11
# TRAUMAT.NO ESP.ABDOM.REG.LUMBOSAC.PELVIS                    11
# NEUMOTORAX TRAUMATICO                                       11
# SINDROME NEFRITICO NO ESPECIFICADO                          11
# GASTROSQUISIS                                               11
# FIBROSIS QUISTICA CON MANIFEST.PULMONARE                    11
# QUEMAD.Y CORROS. MULTIP.REGIONES CUERPO                     11
# OTRAS EMBOLIAS Y TROMBOSIS VENOSAS                          11
# CALCULO DEL RIÒON Y DEL URETER                              11
# TUMOR COMP. INCIERTO O DESC. DEL OVARIO                     11
# MORDEDURA O PICADURA DE INSECTOS Y OTROS                    11
# SINDROME PARALITICO NO ESPECIFICADO                         11
# HERIDA DEL ANTEBRAZO Y DEL CODO                             10
# OTRAS NEUMONIAS DE MICROORG.NO ESPECIFI.                    10
# FISURA PALADAR DURO UNILATERAL                              10
# SINDROME HEMOLITICO-UREMICO                                 10
# TUMEFACCION MASA-PROMINENCIA LOC.CABEZA                     10
# ISQUEMIA CEREBRAL TRANSIT.S/ESPECIFICAC.                    10
# VARICELA                                                    10
# TUMOR MALIG. BRONQUIOS-PULMON NO ESPECIF                    10
# HERIDA DEL CODO                                             10
# TRAUMAT.NO ESPEC.MIEMB.SUP.NIV.NO ESPEC.                    10
# OTRAS PERITONITIS                                           10
# HEM.INTRACEREBRAL HEMISFERIO NO ESPECIFI                    10
# INSUFIC.RESPIRATORIA CRONICA                                10
# LINFADENITIS INESPECIFICA                                   10
# DISPLASIA DEL CUELLO DEL UTERO                              10
# OTROS TRAUMATISMOS DE LA PIERNA, ESPECIF                    10
# FRACTURA DE LA BASE DEL CRANEO                              10
# MORDEDURA O ATAQUE DE PERRO, EN LUGAR NO                    10
# CONSULTA PARA ATENCIÛN Y SUPERVISIÛN DE                     10
# TRASTORNO COGNOSCITIVO LEVE                                 10
# FIS.PALADAR C/LABIO LEPORINO SIN OT.ESPE                    10
# EXANTEMA SUBITO                                             10
# AFECCION ERITEMATOSA NO ESPECIFICADA                        10
# MOLA HIDATIFORME                                            10
# TRAUMATISMO NO ESPECIFICADO DE LA CADERA                    10
# ENFERMEDAD CEREBROVASCULAR NO ESPECIFICA                    10
# AT.A MADRE X OT.COMPL.REL.PR.CON EL EMB.                    10
# HERID.DE MIEMB.INFER.NIVEL NO ESPECIFIC.                    10
# PIELONEFRITISCRON.OBSTRUC.ASOC.C/REFLUJO                    10
# OTRAS EPILEPSIAS                                            10
# OTROS REC.NACID.CON SOBREPESO PARA EDAD                     10
# PIREXIA DE ORIGEN DESCONOCIDO CONSEC.PAR                    10
# FISURA DEL PALADAR CON LABIO LEPORINO                       10
# ENFER.POR VIH RESULT.EN INFECC. X MICROB                    10
# SME DE DEPEND x USO DE ALCOHOL                              10
# PARALISIS DE BELL                                           10
# ESTENOSIS HIPERTROFICA CONG. DEL PILORO                     10
# ESTENOSIS CONG. DE LA VALVULA TRICUSPIDE                    10
# OTRAS DIABETES MELLITUS ESPECIFICADAS                       10
# LUXACIÛN DE LA RODILLA                                      10
# CONTROLES POST TRATAMIENTO c/INSTRUMENT.                    10
# ALUCINACIONES AUDITIVAS                                     10
# POLIURIA                                                    10
# PARO RESPIRATORIO                                           10
# ANEMIA QUE COMPLICA EMBAR, PARTO Y PUERP                    10
# TUM.MALIG.DEL RIÒON EXCEPTO DE LA PELVIS                    10
# CIRUG Y OTRS.PROCED.CAUSA REAC.NORM,C.PS                    10
# EFECTO TOXI.DE OTROS GASES,HUMOS,VAPORES                    10
# PARTO POR CESAREA S/ESPECIFIC.                              10
# TAQUICARDIA SUPRAVENTRICULAR                                 9
# FRACTURAS M˙LTIPLES DE LA PIERNA                             9
# MENINGITIS NO ESPECIFICADA                                   9
# FRACTURA DEL CALC·NEO                                        9
# QUEMAD.MULTIP.REGIONES.GRADO NO ESPECIF.                     9
# TUMEFACCION MASA-PROMINENCIA LOC.TRONCO                      9
# CAIDA EN O DESDE ESCALERA Y ESCALONES                        9
# INFLUENZA C/NEUMONIA VIRUS NO ESPECIF.                       9
# TRAB.PARTO PREMAT.ESPONT.C/PARTO A TERM                      9
# HERIDA DE OTRAS PARTES DEL ANTEBRAZO                         9
# DEFECTO DEL TABIQUE AURICULOVENTRICULAR                      9
# PERS.LES.ACCID.TRANS.VEHIC.MOT.NO ESPEC.                     9
# HERIDA ESCROTO Y TESTICULOS                                  9
# ABSCESO DEL HIGADO                                           9
# HERIDA DE DEDO(S) DE LA MANO, CON DAÒO D                     9
# QUISTE PILONIDAL SIN ABSCESO                                 9
# FRACTURA DE LA DI·FISIS DEL RADIO                            9
# OTRAS ALTERA. DE REGULAC.DE TEMPER.EN RN                     9
# SINOVITIS TRANSITORIA                                        9
# CALC. VESIC. BILIAR CON OTRA COLECISTITI                     9
# HERPES ZOSTER                                                9
# ESPINA BIFIDA NO ESPECIFICADA                                9
# TRAUMATISMO HIGADO Y VESICULA BILIAR                         9
# INFECC.Y REACC.INFLAMAT.DEB.OTR.DISPOSI.                     9
# ...
# TUMOR MALIG. DE LA COSTILLA-ESTERN-CLAVI                     1
# ENFISEMA                                                     1
# HIDROCELE ENQUISTADO                                         1
# GLICOLES                                                     1
# OTROS TRASTORNOS DE LA GLAND.SUPRARRENAL                     1
# POR PERSONA NO ESPECIFICADA                                  1
# PRURIGO NODULAR                                              1
# COLESTEATOMA DEL OIDO EXTERNO                                1
# RINITIS ALERGICA Y VASOMOTORA                                1
# CONTACTO CON OTROS LIQUIDOS CALIENTES                        1
# ESTENOSIS PILORICA HIPERTROF.DEL ADULTO                      1
# OSTEOPATIAS EN ENF.CLASIF.EN OTRA PARTE                      1
# REUMATISMO NO ESPECIFICADO                                   1
# OTRAS ESPONDILOSIS CON MIELOPATIA                            1
# HEPATITIS VIRAL NO ESPECIFICADA SIN COMA                     1
# NEUROPATIA HEREDITARIA E IDIOPATICA                          1
# OTROS TRASTORNOS DE ANSIEDAD ESPECIFIC.                      1
# SEC.QUEMAD.CORROS.Y CONGELAM.NO ESPECIF.                     1
# INFECCIONES LOCALIZ. DEBIDAS A SALMONELA                     1
# APLASIA CRONICA ADQ.EXCLUSIVA SERIE ROJA                     1
# ALOPECIA CONGENITA                                           1
# MALFORMACION CONGE.DE PIEL NO ESPECIFICA                     1
# HALLAZ.ANORM.DIAG.X IMAG.CORAZ.CIRC.CORO                     1
# DROGAS ANTIALERGICAS Y ANTIEMETICAS                          1
# FRACTURA DEL CRANEO DEBID.TRAUMAT.NACIM.                     1
# O.DEFORM.CONG. DE CRANEO-CARA-MANDIBULA                      1
# TUM.MAL.NERV.PERF.MBRO.INF.INCLUI.CADERA                     1
# MALFORM.CONG.VALVULA TRICUSPIDE NO ESPEC                     1
# SÌNDROME NEFRÌTICO AGUDO, NO ESPECIFICAD                     1
# DEFORMIDADES ADQUIRID.DEDOS MANO Y PIE                       1
# MINERALOCORTICOIDES Y SUS ANTAGONISTAS                       1
# TRAUMATISMO NERVIOS CRANEALES NO ESPECIF                     1
# HISTORIA FAMILIAR DE TUMOR MALIGNO                           1
# FIBROSIS QUISTICA CON OTRAS MANIFESTAC.                      1
# OTRAS ENFERMEDADES DEL PERICARDIO                            1
# MARCHA ATAXICA                                               1
# DEFORMIDAD CONGENITA DE LA RODILLA                           1
# TUMOR BENIGNO DEL HUES.Y DEL CART.ARTIC.                     1
# ALTERACIONES DE LA ERUPCION DENTARIA                         1
# ACONDROPLASIA                                                1
# CUIDADOS POSTERIORES A LA CIRUGÌA PL·STI                     1
# NEUMONIA DEB.A HAEMOPHILUS INFLUENZAE                        1
# OTITIS MEDIA SUPURATIVA AGUDA                                1
# ANEMIA FALCIFORME CON CRISIS                                 1
# O.MALF.CONG.DE MIEMB.INF.INCL.CINT.PELVI                     1
# EPILEP.Y SINDROM.EPILEP.SINTOMA.RELAC.LO                     1
# ANTIASMATICOS NO CLASIFIC.EN OTR.PARTE                       1
# MIOPATIA INFLAMAT.NO CLASIF.EN OTRA PART                     1
# SINDROME DE DI GEORGE                                        1
# OTROS ANTIPSICOTICOS Y NEUROLEP.NO ESPEC                     1
# ENCEFALITIS, MIELITIS Y ENCEFALOMIELITIS                     1
# RAQUITISMO ACTIVO                                            1
# BURSITIS SIFILITICA                                          1
# OTROS QUISTES DE LOS MAXILARES                               1
# DEFECTOS POR REDUCCION DEL MIEMBRO INFE.                     1
# ENFERMEDAD RENAL HIPERTENSIVA                                1
# HEMATURIA RECURRENTE Y PERSISTENTE, OTRA                     1
# BRONQUITIS AGUD.DEBIDA A VIRUS SINCITAL                      1
# ICTIOSIS ADQUIRIDA                                           1
# RETARDO DEL DESARROLLO                                       1
# TRAUMATISMO DEL TENDÛN Y M˙SCULO DEL FLE                     1
# ENCEF.MIELIT.ENCEFALOMIEL.ENFERM.VIRALES                     1
# DISPOS.ORTOPED.ASOCIAD.C/INCIDEN.ADVERS.                     1
# ANOMALIA DE LA POSICION DE LA OREJA                          1
# TUM.BENIG.DE OTR.SITIOS Y DE LOS NO ESPE                     1
# NEVO MELANOCITICO SITIO NO ESPECIFICADO                      1
# ESGUINCES Y TORCEDURAS QUE COMPROMETEN E                     1
# TRAST.DE LAS UÒAS                                            1
# FRACTURA DEL MALÈOLO EXTERNO                                 1
# FRACTURA DE LA EPÌFISIS SUPERIOR DEL RAD                     1
# OTR.TRAST.DEL PERITONEO EN ENFERM.INFECC                     1
# OCLUSION Y ESTENOSIS ART. CEREB.NO ESPEC                     1
# SIFILIS SECUNDARIA DE PIEL Y MENBRAN.MUC                     1
# LESION DE SITIOS CONTIGUOS DE LA LENGUA                      1
# FRACTURA DEL HUESO ILIACO                                    1
# OTRAS MIOSITIS                                               1
# CORONAVIRUS C/CASUA DE ENF.CLASIF.OTR.CA                     1
# TUMOR BENIGNO ENCEFALO SUPRATENTORIAL                        1
# ARTRITIS REUMATOIDE JUVENIL                                  1
# SINDROME DE CUSHING                                          1
# TRASTORNO AFECTIVO BIPOLAR NO ESPECIFIC.                     1
# O.TRAUMAT.Y NO ESP.MEDULA ESPINAL TORACI                     1
# AMAUROSIS FUGAZ                                              1
# CIRROSSIS BILIAR SECUNDARIA                                  1
# TUMOR MALIGNO DE LA UNION RECTOSIGMOIDEA                     1
# ENF. DE LAS GLANDULAS SALIVALES                              1
# AUSEN.CONG.ATRESIA-ESTR.CONDUC.AUDI.EXT.                     1
# OREJA SUPERNUMERARIA                                         1
# HEM.INTRAENCEFALICA, INTRAVENTRICULAR                        1
# CUERPO EXTRANO EN EL SACO CONJUNTIVAL                        1
# AMEBIASIS INTESTINAL CRONICA                                 1
# PARASINUSITIS AGUDA                                          1
# EFECTO TOXICO DE DISOLVENTES ORGANICOS                       1
# OTROS HIPOTIROIDISMOS ESPECIFICADOS                          1
# DEFORM.CONG. DEL MUSC.ESTERNOCLEIDOMASTO                     1
# AUS.ATRESIA Y ESTEN.CONG.INTEST.GRUE.NO                      1
# EXAMEN DE SEGUIMIENTO CONSECUTIVO A TRAT                     1
# TRASTORNOS NO ORGANICOS DEL SUEÒO                            1
# MALFORM.CONGEN.DE LA TRAQUEA Y BRONQUIOS                     1
# ESTRABISMO PARALITICO                                        1
# TRAUMAT.X APLASTAMIENTO OTRAS PART.CABEZ                     1
# OTR.TRAST.ESPECIFICADOS DEL METABOLISMO                      1
# HEMORRAGIA SUBARACNOIDEA TRAUMATICA                          1
# OTRAS HEPATITIS VIRALES AGUDAS ESPECIF.                      1
# SUBLUXACION CONG.DE CADERA UNILATERAL                        1
# MALF.CONG.OIDO CAUS.ALT.DE AUDI.S.O.ESP.                     1
# OTROS TRAST.ESPECIF.DEL OJO Y SUS ANEXOS                     1
# MALFORMACIONES CONGENITAS DEL BAZO                           1
# LIPODISTROFIA NO CLASIF.EN OTRA PARTE                        1
# MELANOMA MALIG.CUERO CABELLUDO Y CUELLO                      1
# ESPLENOMEGALIA NO CLASIF. EN OTRA PARTE                      1
# TUBERCULOSIS MILIAR SIN OTRA ESPECIFIC.                      1
# PIOTORAX C/FISTULA                                           1
# CUERPO EXTRANO EN OTR.MULTIP.PART.TUB.DI                     1
# ERITEMA MULTIFORME.                                          1
# FRACTURA DEL PULGAR                                          1
# FRACTURA DE LA EPÌFISIS INFERIOR DEL C˙B                     1
# FLEBITIS Y TROMBOFLEB.INTRCRA.E INTRARAQ                     1
# MACROCEFALIA                                                 1
# INFECCIONES HERPETICAS (HERPES SIMPLE)                       1
# OTROS TRASTORNOS DEL OJO Y SUS ANEXOS                        1
# ACRODERMATITIS  CONTINUA                                     1
# TRASTORNOS DEL METABOLISMO DEL FÛSFORO                       1
# OTRAS DROGAS ANTIINFLAMATORIAS NO ESTERO                     1
# TUM.BENIG.NERV.PERIF.SIST.NERV.AUTONOMO                      1
# HIDROCELE INFECTADO                                          1
# FALTA DE CONSOLIDACION FRACT.SEUDOARTOSI                     1
# OTRAS ENFERMEDADES BACTERIANAS ESPECIF.                      1
# ESCLEROSIS SISTEMICA                                         1
# DERMATITIS SEBORREICA NO ESPECIFICADA                        1
# GONARTROSIS (ARTROSIS DE LA RODILLA)                         1
# ESPINA BIFIDA CERVICAL SIN HIDROCEFALO                       1
# PUBERTAD PRECOZ                                              1
# NEUROFIROMATOSIS (NO MALIGNA)                                1
# HEMATOCOLPOS                                                 1
# GLAUCOMOA SECUNDARIO A OTR.TRAST.DEL OJO                     1
# PROBL.RELAC.C/HECHOS NEGATIVOS EN NIÒEZ                      1
# SEC.QUEMAD.CORROS.Y CONGELAM.MIEMB.INFER                     1
# GLAUCOMA OTRAS ENF. CLASIF.EN OTR.PARTE                      1
# ATROFIA MUSCULAR ESPINAL Y SIND.AFINES.                      1
# VALVULAS URETRALES POSTERIORES CONGENITA                     1
# DUPLICACION DE LA VAGINA                                     1
# ENTERITIS DEBIDA A ROTAVIRUS                                 1
# OTRAS MALFORM.CONG.CONDUCTOS BILIARES                        1
# ENVENENAM.X OTRS.ANTIINFEC,ANTIPARA.SIST                     1
# ESPINA BIFIDA TORACICA SIN HIDROCEFALO                       1
# (OSTEO) ARTROSIS EROSIVA                                     1
# PROBLEMAS RELACIONADOS CON OTROS SERVICI                     1
# OTRAS DISTONIAS                                              1
# OTRAS MALFOR.CONGEN. DE ORGAN.GENIT.MASC                     1
# O.MALF.CONG.ORG.GENITALES MASCULIN.ESPEC                     1
# FIBROSIS QUISTICA NO ESPECIFICADA                            1
# TRAST.DE LOS HABITOS Y DE LOS IMPULSOS                       1
# PROBLEMAS RELACIONADOS CON OTROS HECHOS                      1
# TRISOMIA 13, POR TRANSLOCACION                               1
# MALFORM.CONG.GRANDES ARTERIAS NO ESPECIF                     1
# QUISTES ORIGINADOS X EL DESARR.DE DIENTE                     1
# DIENTES SUPERNUMERARIOS                                      1
# PROLAPSO UTEROVAGINAL SIN OTRA ESPECIFIC                     1
# OTRAS MALFORM.CONGENITAS DEL PULOMON                         1
# ARTRITIS EN LA ENFERMEDAD DE LYME                            1
# OTRAS ANOMALIAS DENTOFACIALES                                1
# QUISTE BILIAR                                                1
# AGENESIA O HIPOPLASIA DE LA NARIZ                            1
# DOLICOCEFALIA                                                1
# OTRAS HEPATITIS CRONICA                                      1
# PROBLEMAS RELACIONADOS CON LA EXPOSICIÛN                     1
# OTROS NEUMOTORAX                                             1
# CORROSION DEL PARPADO Y AREA PERIOCULAR                      1
# UÒA ENCARNADA                                                1
# OTRAS MALFORMACIONES CONG.INTESTINO,ESP.                     1
# TRASTORNOS DE LA ORBITA                                      1
# ESTEN.AGUJEROS INTERVERT.TEJ.CONJ.DIS.IN                     1
# FRACTURAS DE OTRAS PARTES DEL FÈMUR                          1
# ARTROPATIA TRAUMATICA                                        1
# OTROS TRASTORNOS DE LA CONJUNTIVA                            1
# DISCORDANCIA CONEXION VENTRICULOARTERIAL                     1
# BALANITIS XEROTICA OBLITERANTE                               1
# INFLUENZA DEBIDA A VIRUS INFL.IDENTIFIC.                     1
# TESTICULO NO DESCENDIDO                                      1
# PARALISIS DE LAS CUERD.VOCALES Y LARINGE                     1
# SECUELAS DE EFECT.TOXI.DE SUST.PROCEDEN.                     1
# MALFORM.CONG.APARATO URINARIO NO ESPECIF                     1
# LABIO LEPORINO BILATERAL                                     1
# DEFEC.X REDUC.MIEMB.INFERIOR NO ESPECIAL                     1
# OTROS TRASTORNOS DEPRESIVOS RECURRENTES                      1
# SINDROME DE PATAU, NO ESPECIFICADO                           1
# ARTRITIS Y POLIARTRITIS ESTAFILOCOCICA                       1
# POLIPO DE COLON                                              1
# HIPOXIA INTRAUTER.NOTADA X 1ERA VEZ DURA                     1
# PANICULITISAFECT REG.CUELLO Y ESPALDA                        1
# INFECC.ANOGENITAL X VIRUS DEL HERPES SIM                     1
# ATENCIÛN DE LOS APÛSITOS Y SUTURAS                           1
# CONTUSIÛN DE DEDO(S) DEL PIE SIN DAÒO DE                     1
# TOXOPLASMOSIS CON OTRO ORGANO AFECTADO                       1
# HIPOTONIA CONGENITA                                          1
# TRAST.DEL DESARR.DE LOS DIENTES NO ESPE.                     1
# COLITIS INDETERMINADA                                        1
# INTOX AGUDA x MULT DROGAS Y SUST PSICOAC                     1
# ILEOSTOMÌA                                                   1
# MALF.CONG.CAMARAS CARDIACAS CONEX.NO ESP                     1
# MIOCLONIA                                                    1
# TRAUMATISMOS M˙LTIPLES DE LA MUÒECA Y DE                     1
# ATROFIA MUSC.ESPINAL INFANT.TIPO 1                           1
# DEFORMIDAD ADQUIRIDA DE LA NARIZ                             1
# INTOX AGUDA x USO DE SEDANTES O HIPNOTIC                     1
# NEUMONIA CONGENITA                                           1
# O.AFEC.ESP.ASOC.C/ORG.GEN.FEM.Y CICL.MEN                     1
# TUM.MALIGN.DEL HIGAD.Y DE LAS VIAS BILIA                     1
# LESIONES DE LA ENCIA Y DE LA ZONA EDENTU                     1
# NEUMOTORAX ORIGINADO EN PERIOD.PERINAT.                      1
# EXTRACCION DENTARIA                                          1
# ENVEN AUTOINF INTENC X DISOLV ORGAN E HI                     1
# OTRAS FORMAS DE INFECCIONES HERPÈTICAS                       1
# QUISTE PILONIDAL CON ABSCESO                                 1
# GRANULOMA ANULAR                                             1
# TRASTORNO OBSESIVO-COMPULSIVO                                1
# ENVENA.ACCI.X EXPOS.DRG,MEDIC,SUST.BIOL.                     1
# OTRAS COXARTROSIS DISPLASICAS                                1
# TRAUMAT.RAIZ NERVIOSA COLUMNA.LUMB.SACRA                     1
# SUDORACION                                                   1
# INFECC.CONGENIT.X VIRUS DEL HERPES SIMPL                     1
# OTRAS MALF.CONG.DE LA PARED ABDOMINAL                        1
# SIFILIS CONGENITA PRECOZ LATENTE                             1
# OTROS TRASTORNOS VENOSOS ESPECIFICADOS                       1
# O.TRAST.TONO MUSCULAR RECIEN NACIDO                          1
# USO NOCIVO DE COCAINA                                        1
# TRASTORNOS DEL TONO MUSCULAR DEL RN.                         1
# CONTROL GENERAL DE SALUD DE RUTINA DE RE                     1
# OTRAS FORMAS ESPECIFICAS DEL TEMBLOR                         1
# HERPES ZOSTER CON OTRAS COMPLICACIONES                       1
# PEATON LES.ACC.S/E COL.c/VEH.MOT.2-3 RUE                     1
# RETARDO DEL CRECIM.FETAL Y DESNUTRIC.FET                     1
# NEVO MELANOCITICO                                            1
# HIPOGLICEMIA SIN COMA INDUCIDA POR DROGA                     1
# PRESENCIA DE OTRS.IMPLANTES FUNCIONALES                      1
# ABUSO DE SUSTANCIAS QUE NO PRODUCEN DEPE                     1
# T.B.TEJ.CONJ.OTR.TEJ.B.MIE.SUP.INCL.HOMB                     1
# OTRAS MALFORMACIONES CONG. ESPECIFICADAS                     1
# HERNIA INGUINAL BILAT.CON OBSTR.S/GANGRE                     1
# ENFERMEDAD HEMOLITICA DEL FETO Y RN.                         1
# HEMATOMETRA                                                  1
# QUEMAD.2DO GRADO REGION CUERPO NO ESPEC.                     1
# HIPOTENSION ORTOSTATICA                                      1
# CARCINOMA DE CELULAS HEPATICAS                               1
# CONTAC.TRAUM.C/CENTIPOD,MIRIAPODOS VENEN                     1
# PARTO UNICO ASISTIDO S/ESPECIF.                              1
# AT.MAT.X OT.PROBL.FETALES CONOC.O PRESUN                     1
# PLACENT.PREV.C/ESPECIF.QUE NO HUBO HEMOR                     1
# TRASTORNO PERINATAL DEL SISTEMA DIGESTIV                     1
# ENFERMEDAD QUISTICA DEL RIÒON                                1
# HIPERT.PREEXIST.COMPLICA EMB,PARTO Y PUE                     1
# TRAB.DE PARTO OBSTRUID.DEBID.PRESENT.NAL                     1
# Name: count, dtype: int64

# %%
# 1. Contar frecuencia de cada diagnóstico
frecuencias = df_completo["diagnostico_ingreso"].value_counts()

# 2. Identificar los que cumplen con el umbral mínimo
diagnosticos_validos = frecuencias[frecuencias >= 98].index

# 3. Filtrar el DataFrame conservando solo esos diagnósticos
df_completo = df_completo[df_completo["diagnostico_ingreso"].isin(diagnosticos_validos)]

# %%
df_completo["diagnostico_ingreso"].value_counts()
# Out:
# diagnostico_ingreso
# Anomalía dinámica del trabajo de parto                    5414
# COVID-19                                                  3985
# Dolor abdominal y pélvico                                 3979
# Parto único espontáneo                                    2974
# Otros dolores abdominales no especificados                1760
# Diarrea y gastroenteritis de origen infeccioso            1652
# Trabajo de parto prolongado                               1265
# Ruptura prematura de membranas                            1024
# Neumonía                                                   966
# Náuseas y vómitos                                          890
# Cesárea electiva                                           878
# Parto único por cesárea                                    868
# Fiebre                                                     857
# Celulitis                                                  854
# EPOC no especificada                                       829
# Convulsiones no clasificadas                               810
# Traumatismo craneal no especificado                        808
# Dolor torácico                                             779
# Apendicitis aguda                                          773
# Disnea                                                     752
# Traumatismos múltiples                                     737
# Cefalea                                                    650
# Infección urinaria no especificada                         636
# Cólico renal                                               634
# Recién nacidos prematuros                                  628
# Otros traumatismos craneales                               585
# Absceso dental sin fístula                                 553
# Colecistitis                                               526
# Crisis asmática                                            501
# Aborto médico                                              491
# Hipertensión materna                                       478
# Dolor lumbar                                               467
# Dolor abdominal en epigastrio                              467
# Ictericia neonatal                                         461
# Dolor precordial                                           339
# Fiebre no especificada                                     327
# Hipertensión esencial                                      326
# Síncope                                                    316
# ACV agudo no especificado                                  312
# Trabajo de parto prematuro sin parto                       308
# Ingesta de medicamentos                                    301
# Dolor en articulación                                      287
# Nefritis aguda                                             287
# Nefritis no especificada                                   283
# Traumatismo intracraneal                                   277
# Cálculos biliares sin complicaciones                       269
# Otros procedimientos médicos                               255
# Trastornos dentales no especificados                       246
# Hiperglucemia no especificada                              243
# Antecedente de lesión autoinfligida                        239
# Bronquiolitis aguda                                        239
# Mareos y vértigo                                           228
# Herida                                                     224
# Trastornos urinarios no especificados                      220
# Otros procedimientos quirúrgicos                           216
# Pancreatitis aguda                                         210
# Falso trabajo de parto                                     206
# Lumbago no especificado                                    203
# Dolor en extremidad                                        202
# Diabetes tipo 2                                            201
# Contacto con alimentos calientes                           197
# Bronquiolitis no especificada                              191
# Episodio depresivo no especificado                         190
# Convulsiones febriles                                      189
# Fractura de antebrazo                                      188
# Herida en la cabeza                                        185
# Abdomen agudo                                              183
# Control postparto                                          181
# Fractura de muñeca o mano                                  177
# Incompatibilidad ABO neonatal                              171
# Neumonía bacteriana                                        169
# Agresión con arma de fuego                                 169
# Malestar general y fatiga                                  165
# Convulsiones no especificadas                              162
# Alteraciones respiratorias                                 162
# Úlcera crónica de piel                                     161
# Diabetes tipo 1                                            155
# Gastritis no especificada                                  154
# Dificultad respiratoria neonatal                           153
# Caída no especificada                                      152
# Infección cutánea local                                    152
# Insuficiencia cardíaca congestiva                          151
# Observación por sospecha de otras enfermedades             148
# Herida de la pierna                                        146
# Dorsalgia no especificada                                  146
# Aborto espontáneo incompleto                               146
# Síntomas y signos generales no especificados               145
# Esterilización                                             134
# Hernia Inguinal                                            133
# Cuerpo extraño en el tubo digestivo                        130
# EPOC con exacerbación                                      129
# Ascitis                                                    127
# Dolor torácico no especificado                             126
# Cálculos biliares sin colecistitis                         125
# Parto prematuro sin trabajo de parto espontáneo            123
# Fractura de miembro inferior no especificado               123
# Falso trabajo de parto antes de las 37 semanas             121
# Fractura de pierna o tobillo                               119
# Infección renal durante el embarazo                        117
# Diabetes gestacional                                       117
# Sífilis congénita no especificada                          116
# Hernia inguinal unilateral sin obstrucción ni gangrena     114
# Fractura de pierna                                         112
# Uso de drogas y sustancias biológicas no especificadas     111
# Diabetes mellitus no especificada con complicaciones       110
# Intoxicación por sustancias                                110
# Anemia no especificada                                     109
# Hematuria                                                  107
# Tos                                                        105
# Trastornos funcionales intestinales no especificados       104
# Infección urinaria no especificada en el embarazo          103
# Diabetes mellitus no especificada                          103
# Asma                                                        99
# Bronquiolitis                                               98
# Name: count, dtype: int64

# %% [markdown]
# 4.6 `diagnostico_egreso`:

# %%
# 1. Aplicar normalización con el diccionario
df_completo["diagnostico_egreso"] = df_completo["diagnostico_egreso"].replace(diccionario_normalizado)

# 2. Eliminar espacios extra
df_completo["diagnostico_egreso"] = df_completo["diagnostico_egreso"].str.strip()

# 3. Contar frecuencia de cada diagnóstico
frecuencias = df_completo["diagnostico_egreso"].value_counts()

# 4. Identificar los que cumplen con el umbral mínimo
diagnosticos_validos = frecuencias[frecuencias >= 98].index

# 5. Filtrar el DataFrame conservando solo esos diagnósticos
df_completo = df_completo[df_completo["diagnostico_egreso"].isin(diagnosticos_validos)]

# 6. Observamos los valores final
print(df_completo["diagnostico_egreso"].value_counts(dropna=False))
# Out:
# diagnostico_egreso
# Parto único espontáneo                                    9225
# COVID-19                                                  3548
# Cesárea electiva                                          2256
# Otros dolores abdominales no especificados                2008
# Diarrea y gastroenteritis de origen infeccioso            1755
# Neumonía                                                  1264
# Dolor abdominal y pélvico                                 1096
# Colecistitis                                              1077
# Apendicitis aguda                                          997
# Parto único por cesárea                                    927
# Celulitis                                                  797
# EPOC no especificada                                       754
# Infección urinaria no especificada                         728
# Náuseas y vómitos                                          691
# Cólico renal                                               609
# Traumatismo craneal no especificado                        602
# Crisis asmática                                            573
# Dolor torácico                                             568
# Absceso dental sin fístula                                 548
# Otros traumatismos craneales                               542
# Nefritis aguda                                             540
# Convulsiones no clasificadas                               515
# Traumatismo intracraneal                                   502
# Recién nacidos prematuros                                  500
# Traumatismos múltiples                                     489
# Aborto médico                                              487
# Ictericia neonatal                                         453
# Cálculos biliares sin complicaciones                       431
# Pancreatitis aguda                                         421
# Cefalea                                                    420
# Fiebre                                                     357
# Convulsiones no especificadas                              351
# Nefritis no especificada                                   288
# Fiebre no especificada                                     284
# Hipertensión esencial                                      276
# Fractura de la pierna                                      265
# Hipertensión materna                                       261
# Trastornos dentales no especificados                       239
# Trabajo de parto prematuro sin parto                       238
# Antecedente de lesión autoinfligida                        237
# Bronquiolitis aguda                                        227
# Síncope                                                    227
# Hiperglucemia no especificada                              219
# Lumbago no especificado                                    218
# Trastornos urinarios no especificados                      217
# Parto con cesarea de emergencia                            209
# Abdomen agudo                                              207
# Contacto con alimentos calientes                           196
# Convulsiones febriles                                      194
# Ingesta de medicamentos                                    193
# Episodio depresivo no especificado                         182
# Cálculos biliares sin colecistitis                         181
# Control postparto                                          181
# Diabetes tipo 1                                            179
# Incompatibilidad ABO neonatal                              178
# Diabetes tipo 2                                            176
# Gastritis no especificada                                  174
# EPOC con exacerbación                                      173
# Diabetes mellitus no especificada con complicaciones       170
# Insuficiencia cardíaca congestiva                          170
# Enfermedad cerebrovascular                                 167
# Neumonía bacteriana                                        166
# Falso trabajo de parto                                     162
# Hernia inguinal unilateral sin obstrucción ni gangrena     160
# Bronquiolitis no especificada                              160
# Uso de drogas y sustancias biológicas no especificadas     157
# Dolor en articulación                                      156
# Fractura de antebrazo                                      154
# Infección cutánea local                                    153
# Observación por sospecha de otras enfermedades             153
# Mareos y vértigo                                           146
# Dolor en extremidad                                        145
# ACV agudo no especificado                                  143
# Úlcera crónica de piel                                     142
# Ascitis                                                    142
# Disnea                                                     140
# Obstrucción del conducto biliar                            137
# Dolor precordial                                           137
# Esterilización                                             132
# Dificultad respiratoria neonatal                           129
# Dorsalgia no especificada                                  126
# Dolor torácico no especificado                             125
# Cuerpo extraño en el tubo digestivo                        124
# Aborto espontáneo incompleto                               121
# Asma                                                       120
# Sífilis congénita no especificada                          118
# Herida                                                     116
# Bronquiolitis                                              109
# Infección renal durante el embarazo                        105
# Trastornos funcionales intestinales no especificados       100
# Dolor abdominal en epigastrio                               98
# Name: count, dtype: int64

# %% [markdown]
# 4.7 `des_sect`:

# %%
#Observamos los valores originarios de la descripción de los servicios
print(df_completo['des_sect'].unique())
# Out:
# ['AREA DE CUIDADOS INTERMEDIOS ALTOS' 'AREA DE CUIDADOS CRITICOS'
#  'AREA DE CUIDADOS INTERMEDIOS BAJOS' 'AREA DE EMERGENCIA PRIMARIA'
#  'HIC - SALA 1' 'HIC - SALA 2' 'HIC - SHOCK ROOM (CAMILLAS)'
#  'HIC - GUARDIA - (CAMAS)' 'HIC - GUARDIA AISLAMIENTO'
#  'HIC - GUARDIA (CONSULTORIOS)' 'HIC - GUARDIA PASILLO' 'HIC - SALA 3'
#  'HIC - TRIAGE' 'HJBA - SALA 3' 'HJBA - SALA 2: MUJERES'
#  'HJBA - SALA 1: HOMBRES' 'HJBA - INTERNACION TRANSITORIA' 'HNVV - SALA 3'
#  'HNVV - SALA 2' 'HNVV - SALA 1' 'HNVV - GUARDIA' 'HNVV - SALA 4'
#  'HNVV - QUEMADOS' 'HNVV - UTI' 'HNVV - GUARDIA 2'
#  'HRSP - CLINICA MUJERES' 'HRSP - OBSTETRICIA' 'HRSP - GUARDIA PEDIATRICA'
#  'HRSP - SHOCKROOM' 'HRSP - NEONATOLOGIA' 'HRSP - GUARDIA ADULTOS'
#  'HRSP - UCIM' 'HRSP - HOSPITAL DIA GINECOLOGIA'
#  'HRSP - CUIDADOS MULTIPLES' 'HRSP - CLINICA HOMBRES' 'HRSP - GINECOLOGIA'
#  'HRSP - PRE PARTO' 'SECTOR GENERAL' 'ILAR' 'MM - UCIN - NEO'
#  'MM - INTERMEDIO - NEO' 'MM - INTERNACION CONJUNTA - NEO'
#  'MM - RECUPERACION - NEO' 'MM - CUIDADOS MINIMOS - OBSTETRICIA'
#  'MM - CUIDADOS ESPECIALES - OBSTETRICIA' 'MM - ALTO RIESGO - OBSTETRICIA'
#  'MM - PREPARTO' 'SALA CRISIS SANITARIA' 'HIC - SALA 4'
#  'HRSP - CLINICA CRISIS SANITARIA' 'HIC - HOSPITAL DE DIA (CAMAS)'
#  'HRSP - SUM ADULTOS']

# %%
# Diccionario: grupo → lista de palabras clave que identifican ese grupo
grupos_sector = {
    "Guardia":           ["EMERGENCIA", "GUARDIA", "TRIAGE", "SHOCK"],
    "UTI":              ["CRITICOS", "UTI", "UCIM", "CUIDADOS MULTIPLES","INTERMEDIO", "MINIMOS", "RECUPERACION", "ALTO RIESGO","RENAL"],
    "Neonatología":         ["UCIN", "NEO", "NEONATOLOGIA"],
    "Obstetricia/Ginecología": ["OBSTETRICIA", "PREPARTO", "GINECOLOGIA"],
    "Hematología-Oncología": ["HEMATO-ONCO"],
    "Quemados":             ["QUEMADOS"],
    "Sector General": ["SALA", "HOSPITAL DIA", "CRISIS SANITARIA","SECTOR GENERAL"],
   
}

# %%
import re

def agrupar_sector(sector):
    for grupo, keywords in grupos_sector.items():
        # unir las palabras clave en un solo patrón regex (OR)
        pattern = r"(" + "|".join(keywords) + r")"
        if re.search(pattern, sector):
            return grupo
    return "Sector General"

# %%
# Creamos la nueva columna
df_completo["sector_egreso"] = df_completo["des_sect"].apply(agrupar_sector)

# vemos los valores finales para la columna sector_egreso
print(df_completo["sector_egreso"].value_counts())
df_completo.drop(columns='des_sect', inplace=True)
# Out:
# sector_egreso
# Guardia                    17407
# UTI                        12063
# Sector General              8762
# Obstetricia/Ginecología     6696
# Neonatología                1141
# Quemados                     164
# Name: count, dtype: int64

# %%
# Observamos el df final 
df_completo.head()
# Out:
#     mes efector  id_internacion  id_paciente sexo_paciente  edad_paciente  \
# 4     2    HECA               5        19373             M             40
# 6     1    HECA               7        19390             M             18
# 10    1    HECA              11         8008             F             15
# 18    1    HECA              19        19438             M             25
# 21    3    HECA              22        18981             M             76
#
#          diagnostico_ingreso                   diagnostico_egreso  \
# 4     Traumatismos múltiples               Traumatismos múltiples
# 6   Traumatismo intracraneal             Traumatismo intracraneal
# 10        Pancreatitis aguda                   Pancreatitis aguda
# 18    Traumatismos múltiples  Traumatismo craneal no especificado
# 21                      Asma                                 Asma
#
#     tipo_egreso  estadia_dias   año servicio_internacion sector_egreso
# 4   Alta medica            86  2020     Unidad Coronaria           UTI
# 6     Defuncion            63  2020              Cirugía           UTI
# 10  Alta medica            45  2020              Cirugía           UTI
# 18     Traslado            35  2020              Guardia           UTI
# 21  Alta medica            97  2020       Clínica Médica           UTI

# %%
# Descargamos el dataset resultante luego de la limpieza.
df_completo.to_csv("df_internaciones.csv", index=False, encoding="utf-8-sig")
